# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import cv2
from numpy.random import randn
import os
import seaborn as sns
import keras
from keras.models import load_model
from keras.models import Sequential, Model
from keras.layers import Dense, Flatten, Conv2D, Reshape, Input, Conv2DTranspose, Activation, LeakyReLU, BatchNormalization, Dropout, Resizing
from keras.losses import BinaryCrossentropy
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
import warnings
warnings.filterwarnings('ignore')

# config
noise_dimension = 100
batch_size = 64
width, height, channels = 200, 200, 1

# Connect Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Path to the dataset
main_dir = '/content/drive/MyDrive/Healthy'

# loading the dataset => resize images to 128*128*3
images = []
for i in os.listdir(main_dir):
    img_path = os.path.join(main_dir, i)
    print(f"Loading image: {img_path}")

    img = cv2.imread(img_path)

    # Check if the image was loaded successfully
    if img is None:
        print(f"Error loading image: {img_path}")
        continue

    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (200, 200))
    images.append(img)

dataset = np.array(images)

print(dataset.shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Loading image: /content/drive/MyDrive/Healthy/image_007.png
# Loading image: /content/drive/MyDrive/Healthy/image_004.png
# Loading image: /content/drive/MyDrive/Healthy/image_001.png
# Loading image: /content/drive/MyDrive/Healthy/image_003.png
# Loading image: /content/drive/MyDrive/Healthy/image_005.png
# Loading image: /content/drive/MyDrive/Healthy/image_002.png
# Loading image: /content/drive/MyDrive/Healthy/image_006.png
# Loading image: /content/drive/MyDrive/Healthy/image_029.png
# Loading image: /content/drive/MyDrive/Healthy/image_028.png
# Loading image: /content/drive/MyDrive/Healthy/image_015.png
# Loading image: /content/drive/MyDrive/Healthy/image_010.png
# Loading image: /content/drive/MyDrive/Healthy/image_008.png
# Loading image: /content/drive/MyDrive/Healthy/image_023.png
# Loading image: /content/drive/MyDrive/Healthy/image_025.png
# Loading image: /content/drive/MyDrive/Healthy/image_020.png
# Loading image: /content/drive/MyDrive/Healthy/image_019.png
# Loading image: /content/drive/MyDrive/Healthy/image_024.png
# Loading image: /content/drive/MyDrive/Healthy/image_027.png
# Loading image: /content/drive/MyDrive/Healthy/image_030.png
# Loading image: /content/drive/MyDrive/Healthy/image_026.png
# Loading image: /content/drive/MyDrive/Healthy/image_013.png
# Loading image: /content/drive/MyDrive/Healthy/image_016.png
# Loading image: /content/drive/MyDrive/Healthy/image_017.png
# Loading image: /content/drive/MyDrive/Healthy/image_018.png
# Loading image: /content/drive/MyDrive/Healthy/image_009.png
# Loading image: /content/drive/MyDrive/Healthy/image_021.png
# Loading image: /content/drive/MyDrive/Healthy/image_014.png
# Loading image: /content/drive/MyDrive/Healthy/image_012.png
# Loading image: /content/drive/MyDrive/Healthy/image_022.png
# Loading image: /content/drive/MyDrive/Healthy/image_011.png
# Loading image: /content/drive/MyDrive/Healthy/image_042.png
# Loading image: /content/drive/MyDrive/Healthy/image_039.png
# Loading image: /content/drive/MyDrive/Healthy/image_043.png
# Loading image: /content/drive/MyDrive/Healthy/image_037.png
# Loading image: /content/drive/MyDrive/Healthy/image_032.png
# Loading image: /content/drive/MyDrive/Healthy/image_053.png
# Loading image: /content/drive/MyDrive/Healthy/image_033.png
# Loading image: /content/drive/MyDrive/Healthy/image_052.png
# Loading image: /content/drive/MyDrive/Healthy/image_036.png
# Loading image: /content/drive/MyDrive/Healthy/image_047.png
# Loading image: /content/drive/MyDrive/Healthy/image_049.png
# Loading image: /content/drive/MyDrive/Healthy/image_048.png
# Loading image: /content/drive/MyDrive/Healthy/image_031.png
# Loading image: /content/drive/MyDrive/Healthy/image_034.png
# Loading image: /content/drive/MyDrive/Healthy/image_038.png
# Loading image: /content/drive/MyDrive/Healthy/image_044.png
# Loading image: /content/drive/MyDrive/Healthy/image_046.png
# Loading image: /content/drive/MyDrive/Healthy/image_050.png
# Loading image: /content/drive/MyDrive/Healthy/image_041.png
# Loading image: /content/drive/MyDrive/Healthy/image_051.png
# Loading image: /content/drive/MyDrive/Healthy/image_040.png
# Loading image: /content/drive/MyDrive/Healthy/image_045.png
# Loading image: /content/drive/MyDrive/Healthy/image_035.png
# Loading image: /content/drive/MyDrive/Healthy/image_063.png
# Loading image: /content/drive/MyDrive/Healthy/image_083.png
# Loading image: /content/drive/MyDrive/Healthy/image_068.png
# Loading image: /content/drive/MyDrive/Healthy/image_077.png
# Loading image: /content/drive/MyDrive/Healthy/image_073.png
# Loading image: /content/drive/MyDrive/Healthy/image_080.png
# Loading image: /content/drive/MyDrive/Healthy/image_064.png
# Loading image: /content/drive/MyDrive/Healthy/image_055.png
# Loading image: /content/drive/MyDrive/Healthy/image_075.png
# Loading image: /content/drive/MyDrive/Healthy/image_054.png
# Loading image: /content/drive/MyDrive/Healthy/image_081.png
# Loading image: /content/drive/MyDrive/Healthy/image_078.png
# Loading image: /content/drive/MyDrive/Healthy/image_060.png
# Loading image: /content/drive/MyDrive/Healthy/image_066.png
# Loading image: /content/drive/MyDrive/Healthy/image_061.png
# Loading image: /content/drive/MyDrive/Healthy/image_069.png
# Loading image: /content/drive/MyDrive/Healthy/image_070.png
# Loading image: /content/drive/MyDrive/Healthy/image_056.png
# Loading image: /content/drive/MyDrive/Healthy/image_074.png
# Loading image: /content/drive/MyDrive/Healthy/image_057.png
# Loading image: /content/drive/MyDrive/Healthy/image_079.png
# Loading image: /content/drive/MyDrive/Healthy/image_082.png
# Loading image: /content/drive/MyDrive/Healthy/image_058.png
# Loading image: /content/drive/MyDrive/Healthy/image_071.png
# Loading image: /content/drive/MyDrive/Healthy/image_067.png
# Loading image: /content/drive/MyDrive/Healthy/image_062.png
# Loading image: /content/drive/MyDrive/Healthy/image_076.png
# Loading image: /content/drive/MyDrive/Healthy/image_072.png
# Loading image: /content/drive/MyDrive/Healthy/image_065.png
# Loading image: /content/drive/MyDrive/Healthy/image_059.png
# Loading image: /content/drive/MyDrive/Healthy/image_086.png
# Loading image: /content/drive/MyDrive/Healthy/image_106.png
# Loading image: /content/drive/MyDrive/Healthy/image_094.png
# Loading image: /content/drive/MyDrive/Healthy/image_089.png
# Loading image: /content/drive/MyDrive/Healthy/image_093.png
# Loading image: /content/drive/MyDrive/Healthy/image_110.png
# Loading image: /content/drive/MyDrive/Healthy/image_092.png
# Loading image: /content/drive/MyDrive/Healthy/image_090.png
# Loading image: /content/drive/MyDrive/Healthy/image_099.png
# Loading image: /content/drive/MyDrive/Healthy/image_101.png
# Loading image: /content/drive/MyDrive/Healthy/image_096.png
# Loading image: /content/drive/MyDrive/Healthy/image_102.png
# Loading image: /content/drive/MyDrive/Healthy/image_095.png
# Loading image: /content/drive/MyDrive/Healthy/image_103.png
# Loading image: /content/drive/MyDrive/Healthy/image_107.png
# Loading image: /content/drive/MyDrive/Healthy/image_111.png
# Loading image: /content/drive/MyDrive/Healthy/image_098.png
# Loading image: /content/drive/MyDrive/Healthy/image_088.png
# Loading image: /content/drive/MyDrive/Healthy/image_108.png
# Loading image: /content/drive/MyDrive/Healthy/image_087.png
# Loading image: /content/drive/MyDrive/Healthy/image_085.png
# Loading image: /content/drive/MyDrive/Healthy/image_097.png
# Loading image: /content/drive/MyDrive/Healthy/image_104.png
# Loading image: /content/drive/MyDrive/Healthy/image_091.png
# Loading image: /content/drive/MyDrive/Healthy/image_100.png
# Loading image: /content/drive/MyDrive/Healthy/image_084.png
# Loading image: /content/drive/MyDrive/Healthy/image_105.png
# Loading image: /content/drive/MyDrive/Healthy/image_109.png
# Loading image: /content/drive/MyDrive/Healthy/image_113.png
# Loading image: /content/drive/MyDrive/Healthy/image_115.png
# Loading image: /content/drive/MyDrive/Healthy/image_135.png
# Loading image: /content/drive/MyDrive/Healthy/image_112.png
# Loading image: /content/drive/MyDrive/Healthy/image_138.png
# Loading image: /content/drive/MyDrive/Healthy/image_131.png
# Loading image: /content/drive/MyDrive/Healthy/image_118.png
# Loading image: /content/drive/MyDrive/Healthy/image_125.png
# Loading image: /content/drive/MyDrive/Healthy/image_140.png
# Loading image: /content/drive/MyDrive/Healthy/image_137.png
# Loading image: /content/drive/MyDrive/Healthy/image_121.png
# Loading image: /content/drive/MyDrive/Healthy/image_120.png
# Loading image: /content/drive/MyDrive/Healthy/image_134.png
# Loading image: /content/drive/MyDrive/Healthy/image_128.png
# Loading image: /content/drive/MyDrive/Healthy/image_123.png
# Loading image: /content/drive/MyDrive/Healthy/image_119.png
# Loading image: /content/drive/MyDrive/Healthy/image_114.png
# Loading image: /content/drive/MyDrive/Healthy/image_126.png
# Loading image: /content/drive/MyDrive/Healthy/image_136.png
# Loading image: /content/drive/MyDrive/Healthy/image_139.png
# Loading image: /content/drive/MyDrive/Healthy/image_116.png
# Loading image: /content/drive/MyDrive/Healthy/image_133.png
# Loading image: /content/drive/MyDrive/Healthy/image_122.png
# Loading image: /content/drive/MyDrive/Healthy/image_117.png
# Loading image: /content/drive/MyDrive/Healthy/image_124.png
# Loading image: /content/drive/MyDrive/Healthy/image_130.png
# Loading image: /content/drive/MyDrive/Healthy/image_132.png
# Loading image: /content/drive/MyDrive/Healthy/image_127.png
# Loading image: /content/drive/MyDrive/Healthy/image_129.png
# Loading image: /content/drive/MyDrive/Healthy/image_160.png
# Loading image: /content/drive/MyDrive/Healthy/image_144.png
# Loading image: /content/drive/MyDrive/Healthy/image_158.png
# Loading image: /content/drive/MyDrive/Healthy/image_166.png
# Loading image: /content/drive/MyDrive/Healthy/image_149.png
# Loading image: /content/drive/MyDrive/Healthy/image_151.png
# Loading image: /content/drive/MyDrive/Healthy/image_165.png
# Loading image: /content/drive/MyDrive/Healthy/image_146.png
# Loading image: /content/drive/MyDrive/Healthy/image_150.png
# Loading image: /content/drive/MyDrive/Healthy/image_161.png
# Loading image: /content/drive/MyDrive/Healthy/image_148.png
# Loading image: /content/drive/MyDrive/Healthy/image_167.png
# Loading image: /content/drive/MyDrive/Healthy/image_143.png
# Loading image: /content/drive/MyDrive/Healthy/image_153.png
# Loading image: /content/drive/MyDrive/Healthy/image_164.png
# Loading image: /content/drive/MyDrive/Healthy/image_163.png
# Loading image: /content/drive/MyDrive/Healthy/image_152.png
# Loading image: /content/drive/MyDrive/Healthy/image_154.png
# Loading image: /content/drive/MyDrive/Healthy/image_159.png
# Loading image: /content/drive/MyDrive/Healthy/image_142.png
# Loading image: /content/drive/MyDrive/Healthy/image_162.png
# Loading image: /content/drive/MyDrive/Healthy/image_145.png
# Loading image: /content/drive/MyDrive/Healthy/image_157.png
# Loading image: /content/drive/MyDrive/Healthy/image_155.png
# Loading image: /content/drive/MyDrive/Healthy/image_147.png
# Loading image: /content/drive/MyDrive/Healthy/image_141.png
# Loading image: /content/drive/MyDrive/Healthy/image_156.png
# Loading image: /content/drive/MyDrive/Healthy/image_179.png
# Loading image: /content/drive/MyDrive/Healthy/image_197.png
# Loading image: /content/drive/MyDrive/Healthy/image_184.png
# Loading image: /content/drive/MyDrive/Healthy/image_201.png
# Loading image: /content/drive/MyDrive/Healthy/image_172.png
# Loading image: /content/drive/MyDrive/Healthy/image_205.png
# Loading image: /content/drive/MyDrive/Healthy/image_180.png
# Loading image: /content/drive/MyDrive/Healthy/image_199.png
# Loading image: /content/drive/MyDrive/Healthy/image_168.png
# Loading image: /content/drive/MyDrive/Healthy/image_202.png
# Loading image: /content/drive/MyDrive/Healthy/image_194.png
# Loading image: /content/drive/MyDrive/Healthy/image_181.png
# Loading image: /content/drive/MyDrive/Healthy/image_203.png
# Loading image: /content/drive/MyDrive/Healthy/image_188.png
# Loading image: /content/drive/MyDrive/Healthy/image_196.png
# Loading image: /content/drive/MyDrive/Healthy/image_191.png
# Loading image: /content/drive/MyDrive/Healthy/image_183.png
# Loading image: /content/drive/MyDrive/Healthy/image_176.png
# Loading image: /content/drive/MyDrive/Healthy/image_198.png
# Loading image: /content/drive/MyDrive/Healthy/image_190.png
# Loading image: /content/drive/MyDrive/Healthy/image_187.png
# Loading image: /content/drive/MyDrive/Healthy/image_193.png
# Loading image: /content/drive/MyDrive/Healthy/image_182.png
# Loading image: /content/drive/MyDrive/Healthy/image_178.png
# Loading image: /content/drive/MyDrive/Healthy/image_171.png
# Loading image: /content/drive/MyDrive/Healthy/image_174.png
# Loading image: /content/drive/MyDrive/Healthy/image_173.png
# Loading image: /content/drive/MyDrive/Healthy/image_170.png
# Loading image: /content/drive/MyDrive/Healthy/image_189.png
# Loading image: /content/drive/MyDrive/Healthy/image_169.png
# Loading image: /content/drive/MyDrive/Healthy/image_175.png
# Loading image: /content/drive/MyDrive/Healthy/image_177.png
# Loading image: /content/drive/MyDrive/Healthy/image_186.png
# Loading image: /content/drive/MyDrive/Healthy/image_200.png
# Loading image: /content/drive/MyDrive/Healthy/image_204.png
# Loading image: /content/drive/MyDrive/Healthy/image_185.png
# Loading image: /content/drive/MyDrive/Healthy/image_192.png
# Loading image: /content/drive/MyDrive/Healthy/image_195.png
# Loading image: /content/drive/MyDrive/Healthy/image_249.png
# Loading image: /content/drive/MyDrive/Healthy/image_247.png
# Loading image: /content/drive/MyDrive/Healthy/image_210.png
# Loading image: /content/drive/MyDrive/Healthy/image_229.png
# Loading image: /content/drive/MyDrive/Healthy/image_212.png
# Loading image: /content/drive/MyDrive/Healthy/image_216.png
# Loading image: /content/drive/MyDrive/Healthy/image_239.png
# Loading image: /content/drive/MyDrive/Healthy/image_238.png
# Loading image: /content/drive/MyDrive/Healthy/image_246.png
# Loading image: /content/drive/MyDrive/Healthy/image_223.png
# Loading image: /content/drive/MyDrive/Healthy/image_206.png
# Loading image: /content/drive/MyDrive/Healthy/image_222.png
# Loading image: /content/drive/MyDrive/Healthy/image_236.png
# Loading image: /content/drive/MyDrive/Healthy/image_226.png
# Loading image: /content/drive/MyDrive/Healthy/image_209.png
# Loading image: /content/drive/MyDrive/Healthy/image_234.png
# Loading image: /content/drive/MyDrive/Healthy/image_224.png
# Loading image: /content/drive/MyDrive/Healthy/image_221.png
# Loading image: /content/drive/MyDrive/Healthy/image_217.png
# Loading image: /content/drive/MyDrive/Healthy/image_237.png
# Loading image: /content/drive/MyDrive/Healthy/image_213.png
# Loading image: /content/drive/MyDrive/Healthy/image_215.png
# Loading image: /content/drive/MyDrive/Healthy/image_232.png
# Loading image: /content/drive/MyDrive/Healthy/image_235.png
# Loading image: /content/drive/MyDrive/Healthy/image_231.png
# Loading image: /content/drive/MyDrive/Healthy/image_230.png
# Loading image: /content/drive/MyDrive/Healthy/image_211.png
# Loading image: /content/drive/MyDrive/Healthy/image_220.png
# Loading image: /content/drive/MyDrive/Healthy/image_244.png
# Loading image: /content/drive/MyDrive/Healthy/image_214.png
# Loading image: /content/drive/MyDrive/Healthy/image_242.png
# Loading image: /content/drive/MyDrive/Healthy/image_218.png
# Loading image: /content/drive/MyDrive/Healthy/image_233.png
# Loading image: /content/drive/MyDrive/Healthy/image_240.png
# Loading image: /content/drive/MyDrive/Healthy/image_225.png
# Loading image: /content/drive/MyDrive/Healthy/image_208.png
# Loading image: /content/drive/MyDrive/Healthy/image_241.png
# Loading image: /content/drive/MyDrive/Healthy/image_248.png
# Loading image: /content/drive/MyDrive/Healthy/image_228.png
# Loading image: /content/drive/MyDrive/Healthy/image_227.png
# Loading image: /content/drive/MyDrive/Healthy/image_245.png
# Loading image: /content/drive/MyDrive/Healthy/image_207.png
# Loading image: /content/drive/MyDrive/Healthy/image_243.png
# Loading image: /content/drive/MyDrive/Healthy/image_219.png
# Loading image: /content/drive/MyDrive/Healthy/image_290.png
# Loading image: /content/drive/MyDrive/Healthy/image_264.png
# Loading image: /content/drive/MyDrive/Healthy/image_273.png
# Loading image: /content/drive/MyDrive/Healthy/image_252.png
# Loading image: /content/drive/MyDrive/Healthy/image_258.png
# Loading image: /content/drive/MyDrive/Healthy/image_257.png
# Loading image: /content/drive/MyDrive/Healthy/image_276.png
# Loading image: /content/drive/MyDrive/Healthy/image_265.png
# Loading image: /content/drive/MyDrive/Healthy/image_275.png
# Loading image: /content/drive/MyDrive/Healthy/image_278.png
# Loading image: /content/drive/MyDrive/Healthy/image_267.png
# Loading image: /content/drive/MyDrive/Healthy/image_266.png
# Loading image: /content/drive/MyDrive/Healthy/image_269.png
# Loading image: /content/drive/MyDrive/Healthy/image_251.png
# Loading image: /content/drive/MyDrive/Healthy/image_281.png
# Loading image: /content/drive/MyDrive/Healthy/image_274.png
# Loading image: /content/drive/MyDrive/Healthy/image_259.png
# Loading image: /content/drive/MyDrive/Healthy/image_280.png
# Loading image: /content/drive/MyDrive/Healthy/image_279.png
# Loading image: /content/drive/MyDrive/Healthy/image_282.png
# Loading image: /content/drive/MyDrive/Healthy/image_262.png
# Loading image: /content/drive/MyDrive/Healthy/image_284.png
# Loading image: /content/drive/MyDrive/Healthy/image_254.png
# Loading image: /content/drive/MyDrive/Healthy/image_253.png
# Loading image: /content/drive/MyDrive/Healthy/image_288.png
# Loading image: /content/drive/MyDrive/Healthy/image_285.png
# Loading image: /content/drive/MyDrive/Healthy/image_270.png
# Loading image: /content/drive/MyDrive/Healthy/image_263.png
# Loading image: /content/drive/MyDrive/Healthy/image_256.png
# Loading image: /content/drive/MyDrive/Healthy/image_271.png
# Loading image: /content/drive/MyDrive/Healthy/image_255.png
# Loading image: /content/drive/MyDrive/Healthy/image_277.png
# Loading image: /content/drive/MyDrive/Healthy/image_260.png
# Loading image: /content/drive/MyDrive/Healthy/image_286.png
# Loading image: /content/drive/MyDrive/Healthy/image_268.png
# Loading image: /content/drive/MyDrive/Healthy/image_261.png
# Loading image: /content/drive/MyDrive/Healthy/image_289.png
# Loading image: /content/drive/MyDrive/Healthy/image_272.png
# Loading image: /content/drive/MyDrive/Healthy/image_250.png
# Loading image: /content/drive/MyDrive/Healthy/image_283.png
# Loading image: /content/drive/MyDrive/Healthy/image_287.png
# Loading image: /content/drive/MyDrive/Healthy/image_332.png
# Loading image: /content/drive/MyDrive/Healthy/image_316.png
# Loading image: /content/drive/MyDrive/Healthy/image_331.png
# Loading image: /content/drive/MyDrive/Healthy/image_326.png
# Loading image: /content/drive/MyDrive/Healthy/image_305.png
# Loading image: /content/drive/MyDrive/Healthy/image_327.png
# Loading image: /content/drive/MyDrive/Healthy/image_296.png
# Loading image: /content/drive/MyDrive/Healthy/image_325.png
# Loading image: /content/drive/MyDrive/Healthy/image_306.png
# Loading image: /content/drive/MyDrive/Healthy/image_302.png
# Loading image: /content/drive/MyDrive/Healthy/image_328.png
# Loading image: /content/drive/MyDrive/Healthy/image_291.png
# Loading image: /content/drive/MyDrive/Healthy/image_311.png
# Loading image: /content/drive/MyDrive/Healthy/image_299.png
# Loading image: /content/drive/MyDrive/Healthy/image_309.png
# Loading image: /content/drive/MyDrive/Healthy/image_319.png
# Loading image: /content/drive/MyDrive/Healthy/image_312.png
# Loading image: /content/drive/MyDrive/Healthy/image_297.png
# Loading image: /content/drive/MyDrive/Healthy/image_304.png
# Loading image: /content/drive/MyDrive/Healthy/image_303.png
# Loading image: /content/drive/MyDrive/Healthy/image_295.png
# Loading image: /content/drive/MyDrive/Healthy/image_298.png
# Loading image: /content/drive/MyDrive/Healthy/image_330.png
# Loading image: /content/drive/MyDrive/Healthy/image_315.png
# Loading image: /content/drive/MyDrive/Healthy/image_300.png
# Loading image: /content/drive/MyDrive/Healthy/image_323.png
# Loading image: /content/drive/MyDrive/Healthy/image_292.png
# Loading image: /content/drive/MyDrive/Healthy/image_322.png
# Loading image: /content/drive/MyDrive/Healthy/image_308.png
# Loading image: /content/drive/MyDrive/Healthy/image_317.png
# Loading image: /content/drive/MyDrive/Healthy/image_301.png
# Loading image: /content/drive/MyDrive/Healthy/image_321.png
# Loading image: /content/drive/MyDrive/Healthy/image_329.png
# Loading image: /content/drive/MyDrive/Healthy/image_324.png
# Loading image: /content/drive/MyDrive/Healthy/image_310.png
# Loading image: /content/drive/MyDrive/Healthy/image_318.png
# Loading image: /content/drive/MyDrive/Healthy/image_313.png
# Loading image: /content/drive/MyDrive/Healthy/image_307.png
# Loading image: /content/drive/MyDrive/Healthy/image_314.png
# Loading image: /content/drive/MyDrive/Healthy/image_294.png
# Loading image: /content/drive/MyDrive/Healthy/image_293.png
# Loading image: /content/drive/MyDrive/Healthy/image_320.png
# Loading image: /content/drive/MyDrive/Healthy/image_342.png
# Loading image: /content/drive/MyDrive/Healthy/image_362.png
# Loading image: /content/drive/MyDrive/Healthy/image_340.png
# Loading image: /content/drive/MyDrive/Healthy/image_341.png
# Loading image: /content/drive/MyDrive/Healthy/image_352.png
# Loading image: /content/drive/MyDrive/Healthy/image_355.png
# Loading image: /content/drive/MyDrive/Healthy/image_360.png
# Loading image: /content/drive/MyDrive/Healthy/image_351.png
# Loading image: /content/drive/MyDrive/Healthy/image_359.png
# Loading image: /content/drive/MyDrive/Healthy/image_345.png
# Loading image: /content/drive/MyDrive/Healthy/image_335.png
# Loading image: /content/drive/MyDrive/Healthy/image_339.png
# Loading image: /content/drive/MyDrive/Healthy/image_358.png
# Loading image: /content/drive/MyDrive/Healthy/image_357.png
# Loading image: /content/drive/MyDrive/Healthy/image_343.png
# Loading image: /content/drive/MyDrive/Healthy/image_365.png
# Loading image: /content/drive/MyDrive/Healthy/image_350.png
# Loading image: /content/drive/MyDrive/Healthy/image_363.png
# Loading image: /content/drive/MyDrive/Healthy/image_349.png
# Loading image: /content/drive/MyDrive/Healthy/image_333.png
# Loading image: /content/drive/MyDrive/Healthy/image_356.png
# Loading image: /content/drive/MyDrive/Healthy/image_337.png
# Loading image: /content/drive/MyDrive/Healthy/image_361.png
# Loading image: /content/drive/MyDrive/Healthy/image_353.png
# Loading image: /content/drive/MyDrive/Healthy/image_344.png
# Loading image: /content/drive/MyDrive/Healthy/image_338.png
# Loading image: /content/drive/MyDrive/Healthy/image_336.png
# Loading image: /content/drive/MyDrive/Healthy/image_334.png
# Loading image: /content/drive/MyDrive/Healthy/image_346.png
# Loading image: /content/drive/MyDrive/Healthy/image_354.png
# Loading image: /content/drive/MyDrive/Healthy/image_348.png
# Loading image: /content/drive/MyDrive/Healthy/image_347.png
# Loading image: /content/drive/MyDrive/Healthy/image_364.png
# (365, 200, 200)

# %%
X_train = dataset

# Normalize
X_train = (X_train.astype(np.float32) - 127.5) / 127.5
print(X_train.shape)

# Reshape
X_train = X_train.reshape(-1, width, height, channels)

# Save images to Google Colab environment
for i in range(10):
    img = np.expand_dims(X_train[i], axis=2)
    img = np.repeat(img, 3, axis=2)

    # Save images to Colab environment
    cv2.imwrite('/content/greyscale_image_{}.png'.format(i), cv2.cvtColor((img * 127.5 + 127.5).astype(np.uint8), cv2.COLOR_RGB2BGR))

    plt.subplot(2, 5, i + 1)
    plt.imshow(img.squeeze(), cmap='bone')
    plt.axis('off')

plt.tight_layout()
plt.show()

print("No error till now")
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (365, 200, 200)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# No error till now

# %%
def func_generator(noise_dimension):
    n_nodes = 256*50*50
    model = Sequential([
        # the first layes is a 1-D vector so it's a dense layer (not a 2-D convolutional layer)
        # reshape input latent vector into 32x32 as a starting point
        # there are 256*32*32 nodes in the Dense layes and they should be upscaled to 128x128x1 image for output
        Dense(n_nodes, input_dim=noise_dimension),
        LeakyReLU(alpha=0.2),
        Reshape((50, 50, 256)),

        # upsample to 64x64
        Conv2DTranspose(128, (4, 4), strides=2, padding='same'),
        LeakyReLU(alpha=0.2),

        # upsample to 128x128
        Conv2DTranspose(128, (4, 4), strides=2, padding='same'),
        LeakyReLU(alpha=0.2),

        # generate 128*128*1 + the generated images have the value between -1 and 1 (tanh)
        Conv2D(1, (4, 4), padding='same', activation='tanh')])

        # model is not compiled as it's not directly trained like the discriminator, generator is trained via GAN combination model
    return model

G_model = func_generator(noise_dimension)
G_model.summary()

# Discriminator is responsible for classifying the generated images as fake or real
# Binary classification (1 or 0) => sigmoid
# Input: fake / Real Image
# Output: the probability of the image being real
def func_discriminator():
    model = Sequential([
        Conv2D(64, (3, 3), padding='same',input_shape=(width, height, channels)),
        LeakyReLU(alpha=0.2),

        Conv2D(128, (3, 3), strides=2, padding='same'),
        LeakyReLU(alpha=0.2),

        Conv2D(128, (3, 3), strides=2, padding='same'),
        LeakyReLU(alpha=0.2),

        Conv2D(256, (3, 3), strides=2, padding='same'),
        LeakyReLU(alpha=0.2),

        Flatten(),
        Dropout(0.4),
        Dense(1, activation="sigmoid", input_shape=(width, height, channels))])

    model.compile(loss="binary_crossentropy", optimizer=Adam(0.0002, 0.5), metrics=['accuracy'])
    return model

D_model = func_discriminator()
D_model.summary()

# a batch of random real samples to train the GAN on a half batch of real images and another half batch of fake images
# For real images (label 1) and for fake ones (label 0)
def real_samples(dataset, n_samples):
    # choose random images
    indx = np.random.randint(0, dataset.shape[0], n_samples) # dataset.shape = 155
    X = dataset[indx]
    # generate class labels
    y = np.ones((n_samples, 1)) # label 1 to fool discriminator that they are real
    return X, y

# generate points
def generate_latent_points(noise_dimension, n_samples):
    x_input = randn(noise_dimension * n_samples)
    # reshape into a batch of inputs for the network
    x_input = x_input.reshape(n_samples, noise_dimension)
    return x_input

def fake_samples(generator, noise_dimension, n_samples):
    X_input = generate_latent_points(noise_dimension, n_samples) # generating points in latent space
    X = generator.predict(X_input) # generating fake samples
    y = np.zeros((n_samples, 1))  # labels 0 as these samples are fake
    return X, y

# the combined generator and discriminator model, for training and updating the generator
# Discriminator is trained separately (remain constant)
def gan(generator, discriminator):
    discriminator.trainable = False
    model = Sequential()
    model.add(generator)
    model.add(discriminator)

    model.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.00005, beta_1=0.5))
    return model

def show_plot(examples, n, t=0):
    for i in range(n * n):
        plt.subplot(n, n, 1 + i)
        plt.axis('off')
        imgg = cv2.cvtColor(examples[i, :, :, :], cv2.COLOR_GRAY2BGR)
        plt.title(f'epoch {t}')
        # plt.imsave(f'D:\Habib\High resolutation GAN\Inpainting GAN\GAN image creator\Images\epoch_{t}.png', imgg,cmap="bone")
        plt.imshow(examples[i, :, :, :],cmap="bone")
    plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 640000)            64640000
#
#  leaky_re_lu (LeakyReLU)     (None, 640000)            0
#
#  reshape (Reshape)           (None, 50, 50, 256)       0
#
#  conv2d_transpose (Conv2DTr  (None, 100, 100, 128)     524416
#  anspose)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 100, 100, 128)     0
#
#  conv2d_transpose_1 (Conv2D  (None, 200, 200, 128)     262272
#  Transpose)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 200, 200, 128)     0
#
#  conv2d (Conv2D)             (None, 200, 200, 1)       2049
#
# =================================================================
# Total params: 65428737 (249.59 MB)
# Trainable params: 65428737 (249.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 200, 200, 64)      640
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 200, 200, 64)      0
#
#  conv2d_2 (Conv2D)           (None, 100, 100, 128)     73856
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 100, 100, 128)     0
#
#  conv2d_3 (Conv2D)           (None, 50, 50, 128)       147584
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 50, 50, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 25, 25, 256)       295168
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 25, 25, 256)       0
#
#  flatten (Flatten)           (None, 160000)            0
#
#  dropout (Dropout)           (None, 160000)            0
#
#  dense_1 (Dense)             (None, 1)                 160001
#
# =================================================================
# Total params: 677249 (2.58 MB)
# Trainable params: 677249 (2.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.metrics import peak_signal_noise_ratio, structural_similarity as ssim
from tensorflow.keras.models import load_model

psnr_values_list = []
ssim_values_list = []
g_losses = []
d_losses_real = []
d_losses_fake = []

num_epochs = 300

def func_train(gen_model, dis_model, gan_model, dataset, noise_dimension, num_epochs=1000, num_batch=64):
    batch_per_epoch = int(dataset.shape[0] / num_batch)
    half_batch = int(num_batch / 2)

    for i in range(num_epochs):
        for j in range(batch_per_epoch):
            X_real, y_real = real_samples(dataset, half_batch)
            d_loss_real, d_acc_real = dis_model.train_on_batch(X_real, y_real)

            X_fake, y_fake = fake_samples(gen_model, noise_dimension, half_batch)
            d_loss_fake, d_acc_fake = dis_model.train_on_batch(X_fake, y_fake)

            X_gan = generate_latent_points(noise_dimension, num_batch)
            y_gan = np.ones((num_batch, 1))

            g_loss = gan_model.train_on_batch(X_gan, y_gan)

            print('Epoch>%d, Batch %d/%d, d1=%.3f, d2=%.3f g=%.3f' % (i+1, j+1, batch_per_epoch, d_loss_real, d_loss_fake, g_loss))

        # Record losses
        g_losses.append(g_loss)
        d_losses_real.append(d_loss_real)
        d_losses_fake.append(d_loss_fake)

        if i % 50 == 0:
            checkpoint_path = '/content/drive/MyDrive/gan_checkpoints/Chkpt_{}.h5'.format(i)
            gen_model.save(checkpoint_path)
            model = load_model(checkpoint_path)

        if i % 50 == 0:
            # Generate samples for PSNR and SSIM calculation
            latent_points = generate_latent_points(100, 4)
            generated_images = model.predict(latent_points)

            # Rescale generated images from [-1, 1] to [0, 1]
            generated_images = (generated_images + 1) / 2.0

            # Calculate PSNR and SSIM for each generated image
            psnr_values = [peak_signal_noise_ratio(X_train[idx], generated_images[idx]) for idx in range(len(generated_images))]
            ssim_values = [ssim(X_train[idx], generated_images[idx], multichannel=True) for idx in range(len(generated_images))]

            # Append the average PSNR and SSIM to the list
            avg_psnr = np.mean(psnr_values)
            avg_ssim = np.mean(ssim_values)
            psnr_values_list.append(avg_psnr)
            ssim_values_list.append(avg_ssim)

        if i % 50 == 0:
            # Print the average PSNR and SSIM values
            print(f'Epoch {i}, Average PSNR: {avg_psnr:.3f}, Average SSIM: {avg_ssim:.3f}')
            show_plot(generated_images, 2, i)

    # Save the generator model at the end of training
    gen_model.save('/content/drive/MyDrive/Healthy.h5')

    # Plotting the losses and metrics
    plt.figure(figsize=(12, 8))

    plt.subplot(2, 2, 1)
    plt.plot(g_losses, label='Generator Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(2, 2, 2)
    plt.plot(d_losses_real, label='Discriminator Real Loss')
    plt.plot(d_losses_fake, label='Discriminator Fake Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(2, 2, 3)
    plt.plot(psnr_values_list, label='PSNR')
    plt.xlabel('Epoch')
    plt.ylabel('PSNR')
    plt.legend()

    plt.subplot(2, 2, 4)
    plt.plot(ssim_values_list, label='SSIM')
    plt.xlabel('Epoch')
    plt.ylabel('SSIM')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Assuming you have the following functions already defined:
# real_samples, fake_samples, generate_latent_points, show_plot
# and the model functions: func_discriminator, func_generator, gan

dis_model = func_discriminator()
gen_model = func_generator(noise_dimension)
gan_model = gan(gen_model, dis_model)
dataset = X_train

func_train(gen_model, dis_model, gan_model, dataset, noise_dimension, num_epochs)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# 1/1 [==============================] - 3s 3s/step
# Epoch>1, Batch 1/5, d1=0.694, d2=0.697 g=0.694
# 1/1 [==============================] - 0s 17ms/step
# Epoch>1, Batch 2/5, d1=0.621, d2=0.706 g=0.688
# 1/1 [==============================] - 0s 19ms/step
# Epoch>1, Batch 3/5, d1=0.502, d2=0.785 g=0.658
# 1/1 [==============================] - 0s 16ms/step
# Epoch>1, Batch 4/5, d1=0.341, d2=0.924 g=0.730
# 1/1 [==============================] - 0s 18ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch>1, Batch 5/5, d1=0.215, d2=0.666 g=1.216
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1/1 [==============================] - 1s 1s/step
# Epoch 0, Average PSNR: 20.886, Average SSIM: 0.570
# 1/1 [==============================] - 0s 16ms/step
# Epoch>2, Batch 1/5, d1=0.129, d2=0.577 g=1.303
# 1/1 [==============================] - 0s 17ms/step
# Epoch>2, Batch 2/5, d1=0.118, d2=1.064 g=0.777
# 1/1 [==============================] - 0s 15ms/step
# Epoch>2, Batch 3/5, d1=0.174, d2=0.924 g=0.813
# 1/1 [==============================] - 0s 16ms/step
# Epoch>2, Batch 4/5, d1=0.340, d2=0.813 g=0.850
# 1/1 [==============================] - 0s 28ms/step
# Epoch>2, Batch 5/5, d1=0.250, d2=0.884 g=1.017
# 1/1 [==============================] - 0s 34ms/step
# Epoch>3, Batch 1/5, d1=0.218, d2=1.172 g=1.027
# 1/1 [==============================] - 0s 25ms/step
# Epoch>3, Batch 2/5, d1=0.205, d2=6.821 g=0.408
# 1/1 [==============================] - 0s 29ms/step
# Epoch>3, Batch 3/5, d1=0.486, d2=3.173 g=0.794
# 1/1 [==============================] - 0s 27ms/step
# Epoch>3, Batch 4/5, d1=0.712, d2=0.396 g=3.519
# 1/1 [==============================] - 0s 16ms/step
# Epoch>3, Batch 5/5, d1=1.520, d2=0.298 g=1.841
# 1/1 [==============================] - 0s 22ms/step
# Epoch>4, Batch 1/5, d1=0.855, d2=0.660 g=0.818
# 1/1 [==============================] - 0s 16ms/step
# Epoch>4, Batch 2/5, d1=0.851, d2=0.703 g=0.853
# 1/1 [==============================] - 0s 16ms/step
# Epoch>4, Batch 3/5, d1=0.426, d2=0.820 g=0.940
# 1/1 [==============================] - 0s 16ms/step
# Epoch>4, Batch 4/5, d1=0.380, d2=0.816 g=1.040
# 1/1 [==============================] - 0s 16ms/step
# Epoch>4, Batch 5/5, d1=0.534, d2=0.759 g=1.356
# 1/1 [==============================] - 0s 19ms/step
# Epoch>5, Batch 1/5, d1=0.777, d2=0.659 g=1.507
# 1/1 [==============================] - 0s 31ms/step
# Epoch>5, Batch 2/5, d1=0.942, d2=0.436 g=1.191
# 1/1 [==============================] - 0s 33ms/step
# Epoch>5, Batch 3/5, d1=0.914, d2=0.452 g=1.077
# 1/1 [==============================] - 0s 16ms/step
# Epoch>5, Batch 4/5, d1=0.664, d2=0.503 g=0.986
# 1/1 [==============================] - 0s 16ms/step
# Epoch>5, Batch 5/5, d1=0.614, d2=0.521 g=0.941
# 1/1 [==============================] - 0s 16ms/step
# Epoch>6, Batch 1/5, d1=0.577, d2=0.539 g=0.914
# 1/1 [==============================] - 0s 16ms/step
# Epoch>6, Batch 2/5, d1=0.450, d2=0.550 g=0.911
# 1/1 [==============================] - 0s 16ms/step
# Epoch>6, Batch 3/5, d1=0.414, d2=0.537 g=0.926
# 1/1 [==============================] - 0s 16ms/step
# Epoch>6, Batch 4/5, d1=0.419, d2=0.566 g=0.947
# 1/1 [==============================] - 0s 16ms/step
# Epoch>6, Batch 5/5, d1=0.274, d2=0.553 g=1.048
# 1/1 [==============================] - 0s 24ms/step
# Epoch>7, Batch 1/5, d1=0.372, d2=0.487 g=1.297
# 1/1 [==============================] - 0s 27ms/step
# Epoch>7, Batch 2/5, d1=0.284, d2=0.328 g=1.544
# 1/1 [==============================] - 0s 16ms/step
# Epoch>7, Batch 3/5, d1=0.315, d2=0.338 g=1.375
# 1/1 [==============================] - 0s 16ms/step
# Epoch>7, Batch 4/5, d1=0.195, d2=0.356 g=1.281
# 1/1 [==============================] - 0s 22ms/step
# Epoch>7, Batch 5/5, d1=0.118, d2=0.356 g=1.309
# 1/1 [==============================] - 0s 16ms/step
# Epoch>8, Batch 1/5, d1=0.088, d2=0.380 g=1.364
# 1/1 [==============================] - 0s 16ms/step
# Epoch>8, Batch 2/5, d1=0.076, d2=1.424 g=1.239
# 1/1 [==============================] - 0s 18ms/step
# Epoch>8, Batch 3/5, d1=0.137, d2=7.426 g=0.755
# 1/1 [==============================] - 0s 16ms/step
# Epoch>8, Batch 4/5, d1=0.494, d2=5.924 g=0.705
# 1/1 [==============================] - 0s 16ms/step
# Epoch>8, Batch 5/5, d1=0.852, d2=0.514 g=3.756
# 1/1 [==============================] - 0s 34ms/step
# Epoch>9, Batch 1/5, d1=1.265, d2=0.684 g=2.781
# 1/1 [==============================] - 0s 28ms/step
# Epoch>9, Batch 2/5, d1=0.984, d2=0.447 g=1.626
# 1/1 [==============================] - 0s 16ms/step
# Epoch>9, Batch 3/5, d1=0.939, d2=0.493 g=1.096
# 1/1 [==============================] - 0s 16ms/step
# Epoch>9, Batch 4/5, d1=0.925, d2=0.572 g=1.029
# 1/1 [==============================] - 0s 16ms/step
# Epoch>9, Batch 5/5, d1=0.933, d2=0.647 g=0.876
# 1/1 [==============================] - 0s 16ms/step
# Epoch>10, Batch 1/5, d1=0.784, d2=0.613 g=0.872
# 1/1 [==============================] - 0s 16ms/step
# Epoch>10, Batch 2/5, d1=0.763, d2=0.595 g=0.897
# 1/1 [==============================] - 0s 16ms/step
# Epoch>10, Batch 3/5, d1=0.770, d2=0.641 g=0.780
# 1/1 [==============================] - 0s 23ms/step
# Epoch>10, Batch 4/5, d1=0.698, d2=0.678 g=0.737
# 1/1 [==============================] - 0s 27ms/step
# Epoch>10, Batch 5/5, d1=0.666, d2=0.690 g=0.731
# 1/1 [==============================] - 0s 43ms/step
# Epoch>11, Batch 1/5, d1=0.651, d2=0.694 g=0.726
# 1/1 [==============================] - 0s 16ms/step
# Epoch>11, Batch 2/5, d1=0.625, d2=0.694 g=0.725
# 1/1 [==============================] - 0s 16ms/step
# Epoch>11, Batch 3/5, d1=0.580, d2=0.690 g=0.732
# 1/1 [==============================] - 0s 16ms/step
# Epoch>11, Batch 4/5, d1=0.622, d2=0.680 g=0.745
# 1/1 [==============================] - 0s 16ms/step
# Epoch>11, Batch 5/5, d1=0.572, d2=0.667 g=0.782
# 1/1 [==============================] - 0s 16ms/step
# Epoch>12, Batch 1/5, d1=0.545, d2=0.637 g=0.811
# 1/1 [==============================] - 0s 16ms/step
# Epoch>12, Batch 2/5, d1=0.582, d2=0.611 g=0.826
# 1/1 [==============================] - 0s 16ms/step
# Epoch>12, Batch 3/5, d1=0.546, d2=0.628 g=0.832
# 1/1 [==============================] - 0s 31ms/step
# Epoch>12, Batch 4/5, d1=0.493, d2=0.624 g=0.846
# 1/1 [==============================] - 0s 33ms/step
# Epoch>12, Batch 5/5, d1=0.436, d2=0.765 g=0.827
# 1/1 [==============================] - 0s 20ms/step
# Epoch>13, Batch 1/5, d1=0.509, d2=1.102 g=0.773
# 1/1 [==============================] - 0s 16ms/step
# Epoch>13, Batch 2/5, d1=0.610, d2=0.865 g=1.022
# 1/1 [==============================] - 0s 32ms/step
# Epoch>13, Batch 3/5, d1=0.789, d2=0.626 g=1.797
# 1/1 [==============================] - 0s 34ms/step
# Epoch>13, Batch 4/5, d1=1.239, d2=0.344 g=1.685
# 1/1 [==============================] - 0s 22ms/step
# Epoch>13, Batch 5/5, d1=1.115, d2=0.386 g=1.443
# 1/1 [==============================] - 0s 16ms/step
# Epoch>14, Batch 1/5, d1=0.889, d2=0.475 g=1.099
# 1/1 [==============================] - 0s 16ms/step
# Epoch>14, Batch 2/5, d1=0.818, d2=0.503 g=1.002
# 1/1 [==============================] - 0s 32ms/step
# Epoch>14, Batch 3/5, d1=0.753, d2=0.540 g=0.957
# 1/1 [==============================] - 0s 16ms/step
# Epoch>14, Batch 4/5, d1=0.712, d2=0.563 g=0.980
# 1/1 [==============================] - 0s 17ms/step
# Epoch>14, Batch 5/5, d1=0.681, d2=0.633 g=0.886
# 1/1 [==============================] - 0s 17ms/step
# Epoch>15, Batch 1/5, d1=0.627, d2=0.719 g=0.922
# 1/1 [==============================] - 0s 22ms/step
# Epoch>15, Batch 2/5, d1=0.747, d2=0.552 g=1.295
# 1/1 [==============================] - 0s 16ms/step
# Epoch>15, Batch 3/5, d1=0.897, d2=0.487 g=1.142
# 1/1 [==============================] - 0s 16ms/step
# Epoch>15, Batch 4/5, d1=0.852, d2=0.545 g=0.996
# 1/1 [==============================] - 0s 16ms/step
# Epoch>15, Batch 5/5, d1=0.723, d2=0.553 g=1.037
# 1/1 [==============================] - 0s 16ms/step
# Epoch>16, Batch 1/5, d1=0.704, d2=0.558 g=0.989
# 1/1 [==============================] - 0s 29ms/step
# Epoch>16, Batch 2/5, d1=0.721, d2=0.612 g=0.943
# 1/1 [==============================] - 0s 30ms/step
# Epoch>16, Batch 3/5, d1=0.657, d2=0.711 g=0.977
# 1/1 [==============================] - 0s 17ms/step
# Epoch>16, Batch 4/5, d1=0.670, d2=0.537 g=1.128
# 1/1 [==============================] - 0s 16ms/step
# Epoch>16, Batch 5/5, d1=0.789, d2=0.597 g=0.993
# 1/1 [==============================] - 0s 16ms/step
# Epoch>17, Batch 1/5, d1=0.685, d2=0.628 g=0.973
# 1/1 [==============================] - 0s 16ms/step
# Epoch>17, Batch 2/5, d1=0.714, d2=0.617 g=0.907
# 1/1 [==============================] - 0s 16ms/step
# Epoch>17, Batch 3/5, d1=0.672, d2=0.644 g=0.827
# 1/1 [==============================] - 0s 16ms/step
# Epoch>17, Batch 4/5, d1=0.598, d2=0.676 g=0.825
# 1/1 [==============================] - 0s 16ms/step
# Epoch>17, Batch 5/5, d1=0.627, d2=0.676 g=0.886
# 1/1 [==============================] - 0s 35ms/step
# Epoch>18, Batch 1/5, d1=0.690, d2=0.645 g=0.980
# 1/1 [==============================] - 0s 26ms/step
# Epoch>18, Batch 2/5, d1=0.720, d2=0.639 g=0.976
# 1/1 [==============================] - 0s 17ms/step
# Epoch>18, Batch 3/5, d1=0.727, d2=0.667 g=0.829
# 1/1 [==============================] - 0s 16ms/step
# Epoch>18, Batch 4/5, d1=0.709, d2=0.751 g=0.695
# 1/1 [==============================] - 0s 16ms/step
# Epoch>18, Batch 5/5, d1=0.596, d2=0.956 g=0.874
# 1/1 [==============================] - 0s 21ms/step
# Epoch>19, Batch 1/5, d1=0.690, d2=0.703 g=0.744
# 1/1 [==============================] - 0s 18ms/step
# Epoch>19, Batch 2/5, d1=0.711, d2=0.817 g=0.708
# 1/1 [==============================] - 0s 16ms/step
# Epoch>19, Batch 3/5, d1=0.666, d2=0.857 g=0.763
# 1/1 [==============================] - 0s 16ms/step
# Epoch>19, Batch 4/5, d1=0.665, d2=0.666 g=0.818
# 1/1 [==============================] - 0s 34ms/step
# Epoch>19, Batch 5/5, d1=0.722, d2=0.616 g=1.042
# 1/1 [==============================] - 0s 40ms/step
# Epoch>20, Batch 1/5, d1=0.774, d2=0.550 g=1.188
# 1/1 [==============================] - 0s 28ms/step
# Epoch>20, Batch 2/5, d1=0.914, d2=0.600 g=0.903
# 1/1 [==============================] - 0s 16ms/step
# Epoch>20, Batch 3/5, d1=0.751, d2=0.648 g=0.834
# 1/1 [==============================] - 0s 16ms/step
# Epoch>20, Batch 4/5, d1=0.761, d2=0.739 g=0.699
# 1/1 [==============================] - 0s 16ms/step
# Epoch>20, Batch 5/5, d1=0.707, d2=0.768 g=0.674
# 1/1 [==============================] - 0s 16ms/step
# Epoch>21, Batch 1/5, d1=0.683, d2=0.757 g=0.697
# 1/1 [==============================] - 0s 17ms/step
# Epoch>21, Batch 2/5, d1=0.697, d2=0.765 g=0.713
# 1/1 [==============================] - 0s 16ms/step
# Epoch>21, Batch 3/5, d1=0.697, d2=0.742 g=0.672
# 1/1 [==============================] - 0s 16ms/step
# Epoch>21, Batch 4/5, d1=0.665, d2=0.728 g=0.689
# 1/1 [==============================] - 0s 31ms/step
# Epoch>21, Batch 5/5, d1=0.653, d2=0.728 g=0.692
# 1/1 [==============================] - 0s 30ms/step
# Epoch>22, Batch 1/5, d1=0.660, d2=0.732 g=0.690
# 1/1 [==============================] - 0s 16ms/step
# Epoch>22, Batch 2/5, d1=0.623, d2=0.722 g=0.700
# 1/1 [==============================] - 0s 16ms/step
# Epoch>22, Batch 3/5, d1=0.640, d2=0.705 g=0.718
# 1/1 [==============================] - 0s 17ms/step
# Epoch>22, Batch 4/5, d1=0.554, d2=0.682 g=0.744
# 1/1 [==============================] - 0s 17ms/step
# Epoch>22, Batch 5/5, d1=0.572, d2=0.653 g=0.772
# 1/1 [==============================] - 0s 17ms/step
# Epoch>23, Batch 1/5, d1=0.643, d2=0.635 g=0.782
# 1/1 [==============================] - 0s 16ms/step
# Epoch>23, Batch 2/5, d1=0.626, d2=0.632 g=0.783
# 1/1 [==============================] - 0s 27ms/step
# Epoch>23, Batch 3/5, d1=0.599, d2=0.626 g=0.787
# 1/1 [==============================] - 0s 27ms/step
# Epoch>23, Batch 4/5, d1=0.593, d2=0.626 g=0.793
# 1/1 [==============================] - 0s 16ms/step
# Epoch>23, Batch 5/5, d1=0.560, d2=0.623 g=0.797
# 1/1 [==============================] - 0s 16ms/step
# Epoch>24, Batch 1/5, d1=0.497, d2=0.630 g=0.795
# 1/1 [==============================] - 0s 17ms/step
# Epoch>24, Batch 2/5, d1=0.494, d2=0.722 g=0.758
# 1/1 [==============================] - 0s 16ms/step
# Epoch>24, Batch 3/5, d1=0.530, d2=1.349 g=0.616
# 1/1 [==============================] - 0s 17ms/step
# Epoch>24, Batch 4/5, d1=0.570, d2=1.281 g=0.561
# 1/1 [==============================] - 0s 16ms/step
# Epoch>24, Batch 5/5, d1=0.696, d2=1.057 g=0.642
# 1/1 [==============================] - 0s 17ms/step
# Epoch>25, Batch 1/5, d1=0.692, d2=0.737 g=0.848
# 1/1 [==============================] - 0s 41ms/step
# Epoch>25, Batch 2/5, d1=0.731, d2=0.540 g=1.086
# 1/1 [==============================] - 0s 16ms/step
# Epoch>25, Batch 3/5, d1=0.759, d2=0.486 g=1.213
# 1/1 [==============================] - 0s 17ms/step
# Epoch>25, Batch 4/5, d1=0.854, d2=0.501 g=1.105
# 1/1 [==============================] - 0s 17ms/step
# Epoch>25, Batch 5/5, d1=0.878, d2=0.555 g=0.881
# 1/1 [==============================] - 0s 19ms/step
# Epoch>26, Batch 1/5, d1=0.668, d2=0.562 g=0.903
# 1/1 [==============================] - 0s 19ms/step
# Epoch>26, Batch 2/5, d1=0.695, d2=0.589 g=0.853
# 1/1 [==============================] - 0s 17ms/step
# Epoch>26, Batch 3/5, d1=0.589, d2=0.672 g=0.730
# 1/1 [==============================] - 0s 17ms/step
# Epoch>26, Batch 4/5, d1=0.734, d2=0.948 g=0.620
# 1/1 [==============================] - 0s 16ms/step
# Epoch>26, Batch 5/5, d1=0.631, d2=0.949 g=0.687
# 1/1 [==============================] - 0s 33ms/step
# Epoch>27, Batch 1/5, d1=0.730, d2=0.714 g=0.943
# 1/1 [==============================] - 0s 28ms/step
# Epoch>27, Batch 2/5, d1=0.731, d2=0.671 g=0.835
# 1/1 [==============================] - 0s 30ms/step
# Epoch>27, Batch 3/5, d1=0.768, d2=0.688 g=0.718
# 1/1 [==============================] - 0s 16ms/step
# Epoch>27, Batch 4/5, d1=0.764, d2=0.656 g=0.766
# 1/1 [==============================] - 0s 16ms/step
# Epoch>27, Batch 5/5, d1=0.693, d2=0.632 g=0.795
# 1/1 [==============================] - 0s 17ms/step
# Epoch>28, Batch 1/5, d1=0.668, d2=0.614 g=0.814
# 1/1 [==============================] - 0s 16ms/step
# Epoch>28, Batch 2/5, d1=0.706, d2=0.615 g=0.813
# 1/1 [==============================] - 0s 16ms/step
# Epoch>28, Batch 3/5, d1=0.659, d2=0.614 g=0.803
# 1/1 [==============================] - 0s 16ms/step
# Epoch>28, Batch 4/5, d1=0.642, d2=0.645 g=0.775
# 1/1 [==============================] - 0s 23ms/step
# Epoch>28, Batch 5/5, d1=0.666, d2=0.661 g=0.765
# 1/1 [==============================] - 0s 25ms/step
# Epoch>29, Batch 1/5, d1=0.694, d2=0.668 g=0.755
# 1/1 [==============================] - 0s 22ms/step
# Epoch>29, Batch 2/5, d1=0.667, d2=0.678 g=0.753
# 1/1 [==============================] - 0s 16ms/step
# Epoch>29, Batch 3/5, d1=0.642, d2=0.659 g=0.784
# 1/1 [==============================] - 0s 18ms/step
# Epoch>29, Batch 4/5, d1=0.630, d2=0.645 g=0.784
# 1/1 [==============================] - 0s 16ms/step
# Epoch>29, Batch 5/5, d1=0.642, d2=0.648 g=0.777
# 1/1 [==============================] - 0s 21ms/step
# Epoch>30, Batch 1/5, d1=0.595, d2=0.654 g=0.785
# 1/1 [==============================] - 0s 16ms/step
# Epoch>30, Batch 2/5, d1=0.617, d2=0.672 g=0.764
# 1/1 [==============================] - 0s 16ms/step
# Epoch>30, Batch 3/5, d1=0.608, d2=0.730 g=0.735
# 1/1 [==============================] - 0s 17ms/step
# Epoch>30, Batch 4/5, d1=0.551, d2=0.907 g=0.693
# 1/1 [==============================] - 0s 24ms/step
# Epoch>30, Batch 5/5, d1=0.581, d2=1.005 g=0.587
# 1/1 [==============================] - 0s 17ms/step
# Epoch>31, Batch 1/5, d1=0.675, d2=0.901 g=0.657
# 1/1 [==============================] - 0s 16ms/step
# Epoch>31, Batch 2/5, d1=0.690, d2=0.856 g=0.786
# 1/1 [==============================] - 0s 16ms/step
# Epoch>31, Batch 3/5, d1=0.701, d2=0.650 g=0.874
# 1/1 [==============================] - 0s 16ms/step
# Epoch>31, Batch 4/5, d1=0.777, d2=0.561 g=1.053
# 1/1 [==============================] - 0s 16ms/step
# Epoch>31, Batch 5/5, d1=0.709, d2=0.516 g=1.108
# 1/1 [==============================] - 0s 31ms/step
# Epoch>32, Batch 1/5, d1=1.022, d2=0.649 g=0.781
# 1/1 [==============================] - 0s 16ms/step
# Epoch>32, Batch 2/5, d1=0.695, d2=0.640 g=0.845
# 1/1 [==============================] - 0s 16ms/step
# Epoch>32, Batch 3/5, d1=0.709, d2=0.573 g=0.917
# 1/1 [==============================] - 0s 27ms/step
# Epoch>32, Batch 4/5, d1=0.712, d2=0.552 g=0.945
# 1/1 [==============================] - 0s 26ms/step
# Epoch>32, Batch 5/5, d1=0.713, d2=0.566 g=0.879
# 1/1 [==============================] - 0s 17ms/step
# Epoch>33, Batch 1/5, d1=0.679, d2=0.644 g=0.766
# 1/1 [==============================] - 0s 16ms/step
# Epoch>33, Batch 2/5, d1=0.749, d2=0.699 g=0.721
# 1/1 [==============================] - 0s 17ms/step
# Epoch>33, Batch 3/5, d1=0.689, d2=0.700 g=0.810
# 1/1 [==============================] - 0s 17ms/step
# Epoch>33, Batch 4/5, d1=0.717, d2=0.643 g=0.918
# 1/1 [==============================] - 0s 16ms/step
# Epoch>33, Batch 5/5, d1=0.790, d2=0.688 g=0.727
# 1/1 [==============================] - 0s 17ms/step
# Epoch>34, Batch 1/5, d1=0.700, d2=0.677 g=0.754
# 1/1 [==============================] - 0s 16ms/step
# Epoch>34, Batch 2/5, d1=0.683, d2=0.676 g=0.767
# 1/1 [==============================] - 0s 23ms/step
# Epoch>34, Batch 3/5, d1=0.705, d2=0.711 g=0.701
# 1/1 [==============================] - 0s 24ms/step
# Epoch>34, Batch 4/5, d1=0.722, d2=0.740 g=0.669
# 1/1 [==============================] - 0s 17ms/step
# Epoch>34, Batch 5/5, d1=0.669, d2=0.748 g=0.683
# 1/1 [==============================] - 0s 16ms/step
# Epoch>35, Batch 1/5, d1=0.674, d2=0.699 g=0.789
# 1/1 [==============================] - 0s 16ms/step
# Epoch>35, Batch 2/5, d1=0.702, d2=0.666 g=0.793
# 1/1 [==============================] - 0s 17ms/step
# Epoch>35, Batch 3/5, d1=0.718, d2=0.684 g=0.724
# 1/1 [==============================] - 0s 16ms/step
# Epoch>35, Batch 4/5, d1=0.856, d2=0.697 g=0.721
# 1/1 [==============================] - 0s 20ms/step
# Epoch>35, Batch 5/5, d1=0.699, d2=0.674 g=0.748
# 1/1 [==============================] - 0s 16ms/step
# Epoch>36, Batch 1/5, d1=0.685, d2=0.674 g=0.760
# 1/1 [==============================] - 0s 16ms/step
# Epoch>36, Batch 2/5, d1=0.704, d2=0.664 g=0.777
# 1/1 [==============================] - 0s 28ms/step
# Epoch>36, Batch 3/5, d1=0.706, d2=0.645 g=0.804
# 1/1 [==============================] - 0s 33ms/step
# Epoch>36, Batch 4/5, d1=0.709, d2=0.658 g=0.806
# 1/1 [==============================] - 0s 30ms/step
# Epoch>36, Batch 5/5, d1=0.724, d2=0.687 g=0.740
# 1/1 [==============================] - 0s 17ms/step
# Epoch>37, Batch 1/5, d1=0.687, d2=0.749 g=0.675
# 1/1 [==============================] - 0s 16ms/step
# Epoch>37, Batch 2/5, d1=0.701, d2=0.720 g=0.723
# 1/1 [==============================] - 0s 17ms/step
# Epoch>37, Batch 3/5, d1=0.687, d2=0.730 g=0.692
# 1/1 [==============================] - 0s 16ms/step
# Epoch>37, Batch 4/5, d1=0.658, d2=0.728 g=0.685
# 1/1 [==============================] - 0s 16ms/step
# Epoch>37, Batch 5/5, d1=0.677, d2=0.725 g=0.690
# 1/1 [==============================] - 0s 17ms/step
# Epoch>38, Batch 1/5, d1=0.669, d2=0.725 g=0.687
# 1/1 [==============================] - 0s 31ms/step
# Epoch>38, Batch 2/5, d1=0.663, d2=0.731 g=0.688
# 1/1 [==============================] - 0s 16ms/step
# Epoch>38, Batch 3/5, d1=0.656, d2=0.745 g=0.685
# 1/1 [==============================] - 0s 16ms/step
# Epoch>38, Batch 4/5, d1=0.683, d2=0.742 g=0.679
# 1/1 [==============================] - 0s 16ms/step
# Epoch>38, Batch 5/5, d1=0.637, d2=0.725 g=0.690
# 1/1 [==============================] - 0s 16ms/step
# Epoch>39, Batch 1/5, d1=0.627, d2=0.725 g=0.720
# 1/1 [==============================] - 0s 21ms/step
# Epoch>39, Batch 2/5, d1=0.672, d2=0.690 g=0.732
# 1/1 [==============================] - 0s 16ms/step
# Epoch>39, Batch 3/5, d1=0.732, d2=0.721 g=0.716
# 1/1 [==============================] - 0s 16ms/step
# Epoch>39, Batch 4/5, d1=0.687, d2=0.718 g=0.708
# 1/1 [==============================] - 0s 16ms/step
# Epoch>39, Batch 5/5, d1=0.691, d2=0.719 g=0.709
# 1/1 [==============================] - 0s 36ms/step
# Epoch>40, Batch 1/5, d1=0.695, d2=0.709 g=0.709
# 1/1 [==============================] - 0s 42ms/step
# Epoch>40, Batch 2/5, d1=0.690, d2=0.702 g=0.705
# 1/1 [==============================] - 0s 19ms/step
# Epoch>40, Batch 3/5, d1=0.716, d2=0.704 g=0.720
# 1/1 [==============================] - 0s 16ms/step
# Epoch>40, Batch 4/5, d1=0.683, d2=0.698 g=0.709
# 1/1 [==============================] - 0s 16ms/step
# Epoch>40, Batch 5/5, d1=0.703, d2=0.713 g=0.699
# 1/1 [==============================] - 0s 16ms/step
# Epoch>41, Batch 1/5, d1=0.707, d2=0.720 g=0.687
# 1/1 [==============================] - 0s 17ms/step
# Epoch>41, Batch 2/5, d1=0.704, d2=0.727 g=0.679
# 1/1 [==============================] - 0s 16ms/step
# Epoch>41, Batch 3/5, d1=0.696, d2=0.736 g=0.675
# 1/1 [==============================] - 0s 16ms/step
# Epoch>41, Batch 4/5, d1=0.694, d2=0.734 g=0.681
# 1/1 [==============================] - 0s 39ms/step
# Epoch>41, Batch 5/5, d1=0.691, d2=0.728 g=0.680
# 1/1 [==============================] - 0s 28ms/step
# Epoch>42, Batch 1/5, d1=0.674, d2=0.724 g=0.678
# 1/1 [==============================] - 0s 17ms/step
# Epoch>42, Batch 2/5, d1=0.672, d2=0.733 g=0.671
# 1/1 [==============================] - 0s 16ms/step
# Epoch>42, Batch 3/5, d1=0.689, d2=0.731 g=0.675
# 1/1 [==============================] - 0s 16ms/step
# Epoch>42, Batch 4/5, d1=0.665, d2=0.725 g=0.673
# 1/1 [==============================] - 0s 17ms/step
# Epoch>42, Batch 5/5, d1=0.681, d2=0.732 g=0.688
# 1/1 [==============================] - 0s 27ms/step
# Epoch>43, Batch 1/5, d1=0.676, d2=0.717 g=0.705
# 1/1 [==============================] - 0s 16ms/step
# Epoch>43, Batch 2/5, d1=0.686, d2=0.708 g=0.705
# 1/1 [==============================] - 0s 16ms/step
# Epoch>43, Batch 3/5, d1=0.685, d2=0.707 g=0.697
# 1/1 [==============================] - 0s 16ms/step
# Epoch>43, Batch 4/5, d1=0.692, d2=0.714 g=0.694
# 1/1 [==============================] - 0s 30ms/step
# Epoch>43, Batch 5/5, d1=0.683, d2=0.711 g=0.695
# 1/1 [==============================] - 0s 16ms/step
# Epoch>44, Batch 1/5, d1=0.690, d2=0.720 g=0.695
# 1/1 [==============================] - 0s 16ms/step
# Epoch>44, Batch 2/5, d1=0.701, d2=0.714 g=0.696
# 1/1 [==============================] - 0s 16ms/step
# Epoch>44, Batch 3/5, d1=0.677, d2=0.710 g=0.701
# 1/1 [==============================] - 0s 16ms/step
# Epoch>44, Batch 4/5, d1=0.643, d2=0.708 g=0.698
# 1/1 [==============================] - 0s 16ms/step
# Epoch>44, Batch 5/5, d1=0.678, d2=0.715 g=0.693
# 1/1 [==============================] - 0s 16ms/step
# Epoch>45, Batch 1/5, d1=0.654, d2=0.738 g=0.688
# 1/1 [==============================] - 0s 18ms/step
# Epoch>45, Batch 2/5, d1=0.628, d2=0.732 g=0.691
# 1/1 [==============================] - 0s 16ms/step
# Epoch>45, Batch 3/5, d1=0.668, d2=0.728 g=0.715
# 1/1 [==============================] - 0s 25ms/step
# Epoch>45, Batch 4/5, d1=0.701, d2=0.687 g=0.780
# 1/1 [==============================] - 0s 31ms/step
# Epoch>45, Batch 5/5, d1=0.728, d2=0.666 g=0.812
# 1/1 [==============================] - 0s 16ms/step
# Epoch>46, Batch 1/5, d1=0.719, d2=0.673 g=0.778
# 1/1 [==============================] - 0s 16ms/step
# Epoch>46, Batch 2/5, d1=0.765, d2=0.705 g=0.726
# 1/1 [==============================] - 0s 16ms/step
# Epoch>46, Batch 3/5, d1=0.742, d2=0.708 g=0.708
# 1/1 [==============================] - 0s 16ms/step
# Epoch>46, Batch 4/5, d1=0.734, d2=0.686 g=0.727
# 1/1 [==============================] - 0s 17ms/step
# Epoch>46, Batch 5/5, d1=0.714, d2=0.673 g=0.739
# 1/1 [==============================] - 0s 16ms/step
# Epoch>47, Batch 1/5, d1=0.656, d2=0.670 g=0.744
# 1/1 [==============================] - 0s 16ms/step
# Epoch>47, Batch 2/5, d1=0.685, d2=0.679 g=0.741
# 1/1 [==============================] - 0s 33ms/step
# Epoch>47, Batch 3/5, d1=0.696, d2=0.665 g=0.753
# 1/1 [==============================] - 0s 16ms/step
# Epoch>47, Batch 4/5, d1=0.629, d2=0.658 g=0.775
# 1/1 [==============================] - 0s 16ms/step
# Epoch>47, Batch 5/5, d1=0.693, d2=0.645 g=0.763
# 1/1 [==============================] - 0s 16ms/step
# Epoch>48, Batch 1/5, d1=0.632, d2=0.647 g=0.763
# 1/1 [==============================] - 0s 16ms/step
# Epoch>48, Batch 2/5, d1=0.625, d2=0.664 g=0.737
# 1/1 [==============================] - 0s 16ms/step
# Epoch>48, Batch 3/5, d1=0.655, d2=0.784 g=0.652
# 1/1 [==============================] - 0s 16ms/step
# Epoch>48, Batch 4/5, d1=0.685, d2=1.081 g=0.608
# 1/1 [==============================] - 0s 16ms/step
# Epoch>48, Batch 5/5, d1=0.696, d2=0.947 g=0.656
# 1/1 [==============================] - 0s 16ms/step
# Epoch>49, Batch 1/5, d1=0.688, d2=0.704 g=0.737
# 1/1 [==============================] - 0s 31ms/step
# Epoch>49, Batch 2/5, d1=0.712, d2=0.664 g=0.827
# 1/1 [==============================] - 0s 16ms/step
# Epoch>49, Batch 3/5, d1=0.764, d2=0.633 g=0.805
# 1/1 [==============================] - 0s 18ms/step
# Epoch>49, Batch 4/5, d1=0.712, d2=0.642 g=0.852
# 1/1 [==============================] - 0s 16ms/step
# Epoch>49, Batch 5/5, d1=0.714, d2=0.641 g=0.802
# 1/1 [==============================] - 0s 17ms/step
# Epoch>50, Batch 1/5, d1=0.752, d2=0.670 g=0.743
# 1/1 [==============================] - 0s 16ms/step
# Epoch>50, Batch 2/5, d1=0.726, d2=0.697 g=0.726
# 1/1 [==============================] - 0s 16ms/step
# Epoch>50, Batch 3/5, d1=0.709, d2=0.707 g=0.707
# 1/1 [==============================] - 0s 16ms/step
# Epoch>50, Batch 4/5, d1=0.696, d2=0.713 g=0.696
# 1/1 [==============================] - 0s 16ms/step
# Epoch>50, Batch 5/5, d1=0.693, d2=0.711 g=0.701
# 1/1 [==============================] - 0s 34ms/step
# Epoch>51, Batch 1/5, d1=0.680, d2=0.698 g=0.714
# 1/1 [==============================] - 0s 16ms/step
# Epoch>51, Batch 2/5, d1=0.686, d2=0.695 g=0.712
# 1/1 [==============================] - 0s 19ms/step
# Epoch>51, Batch 3/5, d1=0.701, d2=0.695 g=0.712
# 1/1 [==============================] - 0s 16ms/step
# Epoch>51, Batch 4/5, d1=0.673, d2=0.694 g=0.720
# 1/1 [==============================] - 0s 17ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch>51, Batch 5/5, d1=0.666, d2=0.682 g=0.734
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1/1 [==============================] - 0s 81ms/step
# Epoch 50, Average PSNR: 18.938, Average SSIM: 0.671
# 1/1 [==============================] - 0s 16ms/step
# Epoch>52, Batch 1/5, d1=0.703, d2=0.675 g=0.743
# 1/1 [==============================] - 0s 40ms/step
# Epoch>52, Batch 2/5, d1=0.702, d2=0.673 g=0.744
# 1/1 [==============================] - 0s 29ms/step
# Epoch>52, Batch 3/5, d1=0.716, d2=0.663 g=0.744
# 1/1 [==============================] - 0s 33ms/step
# Epoch>52, Batch 4/5, d1=0.685, d2=0.666 g=0.745
# 1/1 [==============================] - 0s 23ms/step
# Epoch>52, Batch 5/5, d1=0.669, d2=0.665 g=0.745
# 1/1 [==============================] - 0s 18ms/step
# Epoch>53, Batch 1/5, d1=0.688, d2=0.664 g=0.744
# 1/1 [==============================] - 0s 17ms/step
# Epoch>53, Batch 2/5, d1=0.697, d2=0.667 g=0.750
# 1/1 [==============================] - 0s 22ms/step
# Epoch>53, Batch 3/5, d1=0.690, d2=0.684 g=0.732
# 1/1 [==============================] - 0s 16ms/step
# Epoch>53, Batch 4/5, d1=0.680, d2=0.680 g=0.720
# 1/1 [==============================] - 0s 17ms/step
# Epoch>53, Batch 5/5, d1=0.657, d2=0.697 g=0.681
# 1/1 [==============================] - 0s 25ms/step
# Epoch>54, Batch 1/5, d1=0.638, d2=0.745 g=0.689
# 1/1 [==============================] - 0s 21ms/step
# Epoch>54, Batch 2/5, d1=0.667, d2=0.815 g=0.671
# 1/1 [==============================] - 0s 16ms/step
# Epoch>54, Batch 3/5, d1=0.649, d2=0.732 g=0.694
# 1/1 [==============================] - 0s 16ms/step
# Epoch>54, Batch 4/5, d1=0.654, d2=0.720 g=0.700
# 1/1 [==============================] - 0s 23ms/step
# Epoch>54, Batch 5/5, d1=0.678, d2=0.751 g=0.813
# 1/1 [==============================] - 0s 19ms/step
# Epoch>55, Batch 1/5, d1=0.723, d2=0.651 g=0.991
# 1/1 [==============================] - 0s 16ms/step
# Epoch>55, Batch 2/5, d1=0.796, d2=0.601 g=0.914
# 1/1 [==============================] - 0s 16ms/step
# Epoch>55, Batch 3/5, d1=0.753, d2=0.607 g=0.829
# 1/1 [==============================] - 0s 22ms/step
# Epoch>55, Batch 4/5, d1=0.779, d2=0.672 g=0.761
# 1/1 [==============================] - 0s 34ms/step
# Epoch>55, Batch 5/5, d1=0.715, d2=0.683 g=0.715
# 1/1 [==============================] - 0s 28ms/step
# Epoch>56, Batch 1/5, d1=0.716, d2=0.699 g=0.709
# 1/1 [==============================] - 0s 17ms/step
# Epoch>56, Batch 2/5, d1=0.722, d2=0.714 g=0.687
# 1/1 [==============================] - 0s 17ms/step
# Epoch>56, Batch 3/5, d1=0.708, d2=0.721 g=0.691
# 1/1 [==============================] - 0s 16ms/step
# Epoch>56, Batch 4/5, d1=0.687, d2=0.719 g=0.697
# 1/1 [==============================] - 0s 16ms/step
# Epoch>56, Batch 5/5, d1=0.697, d2=0.703 g=0.717
# 1/1 [==============================] - 0s 16ms/step
# Epoch>57, Batch 1/5, d1=0.640, d2=0.701 g=0.709
# 1/1 [==============================] - 0s 19ms/step
# Epoch>57, Batch 2/5, d1=0.686, d2=0.701 g=0.714
# 1/1 [==============================] - 0s 16ms/step
# Epoch>57, Batch 3/5, d1=0.633, d2=0.688 g=0.732
# 1/1 [==============================] - 0s 34ms/step
# Epoch>57, Batch 4/5, d1=0.644, d2=0.688 g=0.724
# 1/1 [==============================] - 0s 24ms/step
# Epoch>57, Batch 5/5, d1=0.669, d2=0.712 g=0.685
# 1/1 [==============================] - 0s 16ms/step
# Epoch>58, Batch 1/5, d1=0.677, d2=0.738 g=0.686
# 1/1 [==============================] - 0s 16ms/step
# Epoch>58, Batch 2/5, d1=0.719, d2=0.793 g=0.701
# 1/1 [==============================] - 0s 16ms/step
# Epoch>58, Batch 3/5, d1=0.663, d2=0.756 g=0.687
# 1/1 [==============================] - 0s 17ms/step
# Epoch>58, Batch 4/5, d1=0.698, d2=0.751 g=0.693
# 1/1 [==============================] - 0s 16ms/step
# Epoch>58, Batch 5/5, d1=0.676, d2=0.713 g=0.717
# 1/1 [==============================] - 0s 16ms/step
# Epoch>59, Batch 1/5, d1=0.690, d2=0.697 g=0.772
# 1/1 [==============================] - 0s 17ms/step
# Epoch>59, Batch 2/5, d1=0.728, d2=0.648 g=0.830
# 1/1 [==============================] - 0s 19ms/step
# Epoch>59, Batch 3/5, d1=0.718, d2=0.591 g=0.945
# 1/1 [==============================] - 0s 35ms/step
# Epoch>59, Batch 4/5, d1=0.790, d2=0.644 g=0.773
# 1/1 [==============================] - 0s 38ms/step
# Epoch>59, Batch 5/5, d1=0.776, d2=0.687 g=0.719
# 1/1 [==============================] - 0s 27ms/step
# Epoch>60, Batch 1/5, d1=0.732, d2=0.686 g=0.722
# 1/1 [==============================] - 0s 17ms/step
# Epoch>60, Batch 2/5, d1=0.689, d2=0.687 g=0.720
# 1/1 [==============================] - 0s 17ms/step
# Epoch>60, Batch 3/5, d1=0.670, d2=0.680 g=0.734
# 1/1 [==============================] - 0s 16ms/step
# Epoch>60, Batch 4/5, d1=0.690, d2=0.663 g=0.738
# 1/1 [==============================] - 0s 16ms/step
# Epoch>60, Batch 5/5, d1=0.687, d2=0.663 g=0.749
# 1/1 [==============================] - 0s 16ms/step
# Epoch>61, Batch 1/5, d1=0.646, d2=0.658 g=0.749
# 1/1 [==============================] - 0s 19ms/step
# Epoch>61, Batch 2/5, d1=0.667, d2=0.659 g=0.751
# 1/1 [==============================] - 0s 37ms/step
# Epoch>61, Batch 3/5, d1=0.674, d2=0.662 g=0.749
# 1/1 [==============================] - 0s 29ms/step
# Epoch>61, Batch 4/5, d1=0.678, d2=0.668 g=0.726
# 1/1 [==============================] - 0s 16ms/step
# Epoch>61, Batch 5/5, d1=0.681, d2=0.729 g=0.713
# 1/1 [==============================] - 0s 16ms/step
# Epoch>62, Batch 1/5, d1=0.643, d2=0.770 g=0.697
# 1/1 [==============================] - 0s 16ms/step
# Epoch>62, Batch 2/5, d1=0.627, d2=0.759 g=0.632
# 1/1 [==============================] - 0s 17ms/step
# Epoch>62, Batch 3/5, d1=0.682, d2=0.760 g=0.636
# 1/1 [==============================] - 0s 16ms/step
# Epoch>62, Batch 4/5, d1=0.631, d2=0.757 g=0.635
# 1/1 [==============================] - 0s 17ms/step
# Epoch>62, Batch 5/5, d1=0.694, d2=0.820 g=0.678
# 1/1 [==============================] - 0s 16ms/step
# Epoch>63, Batch 1/5, d1=0.668, d2=0.743 g=0.754
# 1/1 [==============================] - 0s 32ms/step
# Epoch>63, Batch 2/5, d1=0.705, d2=0.631 g=0.873
# 1/1 [==============================] - 0s 23ms/step
# Epoch>63, Batch 3/5, d1=0.798, d2=0.616 g=0.850
# 1/1 [==============================] - 0s 16ms/step
# Epoch>63, Batch 4/5, d1=0.714, d2=0.596 g=0.879
# 1/1 [==============================] - 0s 16ms/step
# Epoch>63, Batch 5/5, d1=0.864, d2=0.681 g=0.722
# 1/1 [==============================] - 0s 16ms/step
# Epoch>64, Batch 1/5, d1=0.683, d2=0.700 g=0.715
# 1/1 [==============================] - 0s 16ms/step
# Epoch>64, Batch 2/5, d1=0.694, d2=0.695 g=0.729
# 1/1 [==============================] - 0s 20ms/step
# Epoch>64, Batch 3/5, d1=0.698, d2=0.672 g=0.755
# 1/1 [==============================] - 0s 16ms/step
# Epoch>64, Batch 4/5, d1=0.704, d2=0.671 g=0.743
# 1/1 [==============================] - 0s 16ms/step
# Epoch>64, Batch 5/5, d1=0.705, d2=0.684 g=0.721
# 1/1 [==============================] - 0s 35ms/step
# Epoch>65, Batch 1/5, d1=0.696, d2=0.685 g=0.729
# 1/1 [==============================] - 0s 36ms/step
# Epoch>65, Batch 2/5, d1=0.706, d2=0.674 g=0.758
# 1/1 [==============================] - 0s 16ms/step
# Epoch>65, Batch 3/5, d1=0.693, d2=0.689 g=0.723
# 1/1 [==============================] - 0s 17ms/step
# Epoch>65, Batch 4/5, d1=0.701, d2=0.685 g=0.725
# 1/1 [==============================] - 0s 16ms/step
# Epoch>65, Batch 5/5, d1=0.674, d2=0.674 g=0.741
# 1/1 [==============================] - 0s 16ms/step
# Epoch>66, Batch 1/5, d1=0.710, d2=0.666 g=0.738
# 1/1 [==============================] - 0s 16ms/step
# Epoch>66, Batch 2/5, d1=0.684, d2=0.678 g=0.724
# 1/1 [==============================] - 0s 17ms/step
# Epoch>66, Batch 3/5, d1=0.688, d2=0.702 g=0.701
# 1/1 [==============================] - 0s 16ms/step
# Epoch>66, Batch 4/5, d1=0.697, d2=0.705 g=0.706
# 1/1 [==============================] - 0s 32ms/step
# Epoch>66, Batch 5/5, d1=0.670, d2=0.700 g=0.731
# 1/1 [==============================] - 0s 35ms/step
# Epoch>67, Batch 1/5, d1=0.690, d2=0.690 g=0.715
# 1/1 [==============================] - 0s 31ms/step
# Epoch>67, Batch 2/5, d1=0.700, d2=0.715 g=0.711
# 1/1 [==============================] - 0s 16ms/step
# Epoch>67, Batch 3/5, d1=0.682, d2=0.706 g=0.715
# 1/1 [==============================] - 0s 16ms/step
# Epoch>67, Batch 4/5, d1=0.668, d2=0.684 g=0.722
# 1/1 [==============================] - 0s 16ms/step
# Epoch>67, Batch 5/5, d1=0.673, d2=0.688 g=0.720
# 1/1 [==============================] - 0s 16ms/step
# Epoch>68, Batch 1/5, d1=0.694, d2=0.686 g=0.744
# 1/1 [==============================] - 0s 16ms/step
# Epoch>68, Batch 2/5, d1=0.694, d2=0.674 g=0.732
# 1/1 [==============================] - 0s 16ms/step
# Epoch>68, Batch 3/5, d1=0.695, d2=0.692 g=0.719
# 1/1 [==============================] - 0s 22ms/step
# Epoch>68, Batch 4/5, d1=0.699, d2=0.703 g=0.696
# 1/1 [==============================] - 0s 34ms/step
# Epoch>68, Batch 5/5, d1=0.696, d2=0.711 g=0.714
# 1/1 [==============================] - 0s 36ms/step
# Epoch>69, Batch 1/5, d1=0.682, d2=0.695 g=0.723
# 1/1 [==============================] - 0s 16ms/step
# Epoch>69, Batch 2/5, d1=0.650, d2=0.710 g=0.699
# 1/1 [==============================] - 0s 17ms/step
# Epoch>69, Batch 3/5, d1=0.657, d2=0.726 g=0.690
# 1/1 [==============================] - 0s 18ms/step
# Epoch>69, Batch 4/5, d1=0.688, d2=0.726 g=0.692
# 1/1 [==============================] - 0s 17ms/step
# Epoch>69, Batch 5/5, d1=0.683, d2=0.713 g=0.708
# 1/1 [==============================] - 0s 16ms/step
# Epoch>70, Batch 1/5, d1=0.678, d2=0.689 g=0.735
# 1/1 [==============================] - 0s 17ms/step
# Epoch>70, Batch 2/5, d1=0.701, d2=0.690 g=0.735
# 1/1 [==============================] - 0s 16ms/step
# Epoch>70, Batch 3/5, d1=0.703, d2=0.687 g=0.734
# 1/1 [==============================] - 0s 29ms/step
# Epoch>70, Batch 4/5, d1=0.703, d2=0.687 g=0.734
# 1/1 [==============================] - 0s 26ms/step
# Epoch>70, Batch 5/5, d1=0.724, d2=0.685 g=0.739
# 1/1 [==============================] - 0s 17ms/step
# Epoch>71, Batch 1/5, d1=0.703, d2=0.677 g=0.747
# 1/1 [==============================] - 0s 16ms/step
# Epoch>71, Batch 2/5, d1=0.698, d2=0.699 g=0.714
# 1/1 [==============================] - 0s 16ms/step
# Epoch>71, Batch 3/5, d1=0.702, d2=0.687 g=0.719
# 1/1 [==============================] - 0s 16ms/step
# Epoch>71, Batch 4/5, d1=0.683, d2=0.688 g=0.739
# 1/1 [==============================] - 0s 16ms/step
# Epoch>71, Batch 5/5, d1=0.696, d2=0.686 g=0.732
# 1/1 [==============================] - 0s 16ms/step
# Epoch>72, Batch 1/5, d1=0.700, d2=0.689 g=0.712
# 1/1 [==============================] - 0s 18ms/step
# Epoch>72, Batch 2/5, d1=0.676, d2=0.710 g=0.709
# 1/1 [==============================] - 0s 37ms/step
# Epoch>72, Batch 3/5, d1=0.664, d2=0.707 g=0.718
# 1/1 [==============================] - 0s 37ms/step
# Epoch>72, Batch 4/5, d1=0.683, d2=0.690 g=0.750
# 1/1 [==============================] - 0s 25ms/step
# Epoch>72, Batch 5/5, d1=0.707, d2=0.669 g=0.743
# 1/1 [==============================] - 0s 17ms/step
# Epoch>73, Batch 1/5, d1=0.706, d2=0.685 g=0.732
# 1/1 [==============================] - 0s 19ms/step
# Epoch>73, Batch 2/5, d1=0.697, d2=0.697 g=0.716
# 1/1 [==============================] - 0s 16ms/step
# Epoch>73, Batch 3/5, d1=0.693, d2=0.710 g=0.728
# 1/1 [==============================] - 0s 16ms/step
# Epoch>73, Batch 4/5, d1=0.701, d2=0.674 g=0.759
# 1/1 [==============================] - 0s 16ms/step
# Epoch>73, Batch 5/5, d1=0.722, d2=0.653 g=0.767
# 1/1 [==============================] - 0s 25ms/step
# Epoch>74, Batch 1/5, d1=0.692, d2=0.657 g=0.769
# 1/1 [==============================] - 0s 40ms/step
# Epoch>74, Batch 2/5, d1=0.704, d2=0.669 g=0.755
# 1/1 [==============================] - 0s 17ms/step
# Epoch>74, Batch 3/5, d1=0.688, d2=0.676 g=0.743
# 1/1 [==============================] - 0s 16ms/step
# Epoch>74, Batch 4/5, d1=0.649, d2=0.672 g=0.786
# 1/1 [==============================] - 0s 25ms/step
# Epoch>74, Batch 5/5, d1=0.642, d2=0.718 g=0.730
# 1/1 [==============================] - 0s 16ms/step
# Epoch>75, Batch 1/5, d1=0.735, d2=0.755 g=0.680
# 1/1 [==============================] - 0s 16ms/step
# Epoch>75, Batch 2/5, d1=0.644, d2=0.770 g=0.707
# 1/1 [==============================] - 0s 17ms/step
# Epoch>75, Batch 3/5, d1=0.677, d2=0.701 g=0.776
# 1/1 [==============================] - 0s 16ms/step
# Epoch>75, Batch 4/5, d1=0.718, d2=0.638 g=0.817
# 1/1 [==============================] - 0s 18ms/step
# Epoch>75, Batch 5/5, d1=0.731, d2=0.620 g=0.864
# 1/1 [==============================] - 0s 36ms/step
# Epoch>76, Batch 1/5, d1=0.716, d2=0.619 g=0.848
# 1/1 [==============================] - 0s 38ms/step
# Epoch>76, Batch 2/5, d1=0.790, d2=0.664 g=0.735
# 1/1 [==============================] - 0s 16ms/step
# Epoch>76, Batch 3/5, d1=0.723, d2=0.674 g=0.742
# 1/1 [==============================] - 0s 17ms/step
# Epoch>76, Batch 4/5, d1=0.678, d2=0.664 g=0.748
# 1/1 [==============================] - 0s 18ms/step
# Epoch>76, Batch 5/5, d1=0.729, d2=0.679 g=0.733
# 1/1 [==============================] - 0s 16ms/step
# Epoch>77, Batch 1/5, d1=0.715, d2=0.690 g=0.725
# 1/1 [==============================] - 0s 16ms/step
# Epoch>77, Batch 2/5, d1=0.674, d2=0.687 g=0.743
# 1/1 [==============================] - 0s 16ms/step
# Epoch>77, Batch 3/5, d1=0.675, d2=0.677 g=0.731
# 1/1 [==============================] - 0s 17ms/step
# Epoch>77, Batch 4/5, d1=0.680, d2=0.697 g=0.712
# 1/1 [==============================] - 0s 37ms/step
# Epoch>77, Batch 5/5, d1=0.672, d2=0.688 g=0.731
# 1/1 [==============================] - 0s 36ms/step
# Epoch>78, Batch 1/5, d1=0.661, d2=0.681 g=0.750
# 1/1 [==============================] - 0s 36ms/step
# Epoch>78, Batch 2/5, d1=0.711, d2=0.695 g=0.720
# 1/1 [==============================] - 0s 17ms/step
# Epoch>78, Batch 3/5, d1=0.652, d2=0.722 g=0.705
# 1/1 [==============================] - 0s 17ms/step
# Epoch>78, Batch 4/5, d1=0.671, d2=0.731 g=0.697
# 1/1 [==============================] - 0s 17ms/step
# Epoch>78, Batch 5/5, d1=0.690, d2=0.699 g=0.715
# 1/1 [==============================] - 0s 17ms/step
# Epoch>79, Batch 1/5, d1=0.677, d2=0.676 g=0.777
# 1/1 [==============================] - 0s 16ms/step
# Epoch>79, Batch 2/5, d1=0.690, d2=0.668 g=0.763
# 1/1 [==============================] - 0s 17ms/step
# Epoch>79, Batch 3/5, d1=0.727, d2=0.687 g=0.724
# 1/1 [==============================] - 0s 16ms/step
# Epoch>79, Batch 4/5, d1=0.681, d2=0.706 g=0.724
# 1/1 [==============================] - 0s 36ms/step
# Epoch>79, Batch 5/5, d1=0.691, d2=0.675 g=0.761
# 1/1 [==============================] - 0s 38ms/step
# Epoch>80, Batch 1/5, d1=0.689, d2=0.645 g=0.791
# 1/1 [==============================] - 0s 29ms/step
# Epoch>80, Batch 2/5, d1=0.679, d2=0.631 g=0.803
# 1/1 [==============================] - 0s 17ms/step
# Epoch>80, Batch 3/5, d1=0.717, d2=0.661 g=0.744
# 1/1 [==============================] - 0s 16ms/step
# Epoch>80, Batch 4/5, d1=0.707, d2=0.712 g=0.703
# 1/1 [==============================] - 0s 16ms/step
# Epoch>80, Batch 5/5, d1=0.712, d2=0.702 g=0.831
# 1/1 [==============================] - 0s 16ms/step
# Epoch>81, Batch 1/5, d1=0.683, d2=0.686 g=0.786
# 1/1 [==============================] - 0s 22ms/step
# Epoch>81, Batch 2/5, d1=0.697, d2=0.691 g=0.718
# 1/1 [==============================] - 0s 19ms/step
# Epoch>81, Batch 3/5, d1=0.678, d2=0.673 g=0.745
# 1/1 [==============================] - 0s 16ms/step
# Epoch>81, Batch 4/5, d1=0.666, d2=0.664 g=0.766
# 1/1 [==============================] - 0s 40ms/step
# Epoch>81, Batch 5/5, d1=0.684, d2=0.636 g=0.804
# 1/1 [==============================] - 0s 40ms/step
# Epoch>82, Batch 1/5, d1=0.681, d2=0.628 g=0.820
# 1/1 [==============================] - 0s 16ms/step
# Epoch>82, Batch 2/5, d1=0.696, d2=0.636 g=0.805
# 1/1 [==============================] - 0s 16ms/step
# Epoch>82, Batch 3/5, d1=0.684, d2=0.636 g=0.801
# 1/1 [==============================] - 0s 17ms/step
# Epoch>82, Batch 4/5, d1=0.680, d2=0.648 g=0.771
# 1/1 [==============================] - 0s 18ms/step
# Epoch>82, Batch 5/5, d1=0.683, d2=0.663 g=0.752
# 1/1 [==============================] - 0s 16ms/step
# Epoch>83, Batch 1/5, d1=0.656, d2=0.694 g=0.731
# 1/1 [==============================] - 0s 18ms/step
# Epoch>83, Batch 2/5, d1=0.647, d2=0.685 g=0.763
# 1/1 [==============================] - 0s 18ms/step
# Epoch>83, Batch 3/5, d1=0.650, d2=0.681 g=0.755
# 1/1 [==============================] - 0s 30ms/step
# Epoch>83, Batch 4/5, d1=0.611, d2=0.713 g=0.701
# 1/1 [==============================] - 0s 43ms/step
# Epoch>83, Batch 5/5, d1=0.661, d2=0.753 g=0.726
# 1/1 [==============================] - 0s 30ms/step
# Epoch>84, Batch 1/5, d1=0.632, d2=0.739 g=0.760
# 1/1 [==============================] - 0s 33ms/step
# Epoch>84, Batch 2/5, d1=0.643, d2=0.666 g=0.810
# 1/1 [==============================] - 0s 28ms/step
# Epoch>84, Batch 3/5, d1=0.667, d2=0.632 g=0.818
# 1/1 [==============================] - 0s 16ms/step
# Epoch>84, Batch 4/5, d1=0.641, d2=0.664 g=0.771
# 1/1 [==============================] - 0s 16ms/step
# Epoch>84, Batch 5/5, d1=0.624, d2=0.635 g=0.866
# 1/1 [==============================] - 0s 16ms/step
# Epoch>85, Batch 1/5, d1=0.641, d2=0.613 g=0.862
# 1/1 [==============================] - 0s 22ms/step
# Epoch>85, Batch 2/5, d1=0.654, d2=0.595 g=0.856
# 1/1 [==============================] - 0s 34ms/step
# Epoch>85, Batch 3/5, d1=0.562, d2=0.591 g=0.851
# 1/1 [==============================] - 0s 31ms/step
# Epoch>85, Batch 4/5, d1=0.654, d2=0.748 g=0.702
# 1/1 [==============================] - 0s 16ms/step
# Epoch>85, Batch 5/5, d1=0.679, d2=0.958 g=0.603
# 1/1 [==============================] - 0s 17ms/step
# Epoch>86, Batch 1/5, d1=0.644, d2=0.805 g=0.823
# 1/1 [==============================] - 0s 16ms/step
# Epoch>86, Batch 2/5, d1=0.705, d2=0.699 g=0.981
# 1/1 [==============================] - 0s 17ms/step
# Epoch>86, Batch 3/5, d1=0.783, d2=0.514 g=1.215
# 1/1 [==============================] - 0s 22ms/step
# Epoch>86, Batch 4/5, d1=0.782, d2=0.621 g=0.959
# 1/1 [==============================] - 0s 16ms/step
# Epoch>86, Batch 5/5, d1=0.793, d2=0.531 g=1.054
# 1/1 [==============================] - 0s 16ms/step
# Epoch>87, Batch 1/5, d1=0.716, d2=0.600 g=0.857
# 1/1 [==============================] - 0s 27ms/step
# Epoch>87, Batch 2/5, d1=0.754, d2=0.758 g=0.845
# 1/1 [==============================] - 0s 31ms/step
# Epoch>87, Batch 3/5, d1=0.653, d2=0.642 g=0.863
# 1/1 [==============================] - 0s 17ms/step
# Epoch>87, Batch 4/5, d1=0.732, d2=0.585 g=0.875
# 1/1 [==============================] - 0s 16ms/step
# Epoch>87, Batch 5/5, d1=0.695, d2=0.550 g=0.912
# 1/1 [==============================] - 0s 20ms/step
# Epoch>88, Batch 1/5, d1=0.664, d2=0.556 g=0.900
# 1/1 [==============================] - 0s 16ms/step
# Epoch>88, Batch 2/5, d1=0.635, d2=0.610 g=0.877
# 1/1 [==============================] - 0s 17ms/step
# Epoch>88, Batch 3/5, d1=0.615, d2=0.638 g=0.814
# 1/1 [==============================] - 0s 18ms/step
# Epoch>88, Batch 4/5, d1=0.598, d2=0.615 g=1.195
# 1/1 [==============================] - 0s 19ms/step
# Epoch>88, Batch 5/5, d1=0.598, d2=0.566 g=0.890
# 1/1 [==============================] - 0s 16ms/step
# Epoch>89, Batch 1/5, d1=0.671, d2=0.564 g=0.898
# 1/1 [==============================] - 0s 26ms/step
# Epoch>89, Batch 2/5, d1=0.528, d2=0.532 g=0.947
# 1/1 [==============================] - 0s 16ms/step
# Epoch>89, Batch 3/5, d1=0.651, d2=0.534 g=0.994
# 1/1 [==============================] - 0s 17ms/step
# Epoch>89, Batch 4/5, d1=0.564, d2=0.522 g=0.978
# 1/1 [==============================] - 0s 17ms/step
# Epoch>89, Batch 5/5, d1=0.473, d2=1.602 g=0.749
# 1/1 [==============================] - 0s 16ms/step
# Epoch>90, Batch 1/5, d1=0.620, d2=1.549 g=1.057
# 1/1 [==============================] - 0s 19ms/step
# Epoch>90, Batch 2/5, d1=0.852, d2=0.441 g=2.324
# 1/1 [==============================] - 0s 16ms/step
# Epoch>90, Batch 3/5, d1=0.952, d2=0.365 g=1.926
# 1/1 [==============================] - 0s 16ms/step
# Epoch>90, Batch 4/5, d1=0.797, d2=0.471 g=1.239
# 1/1 [==============================] - 0s 16ms/step
# Epoch>90, Batch 5/5, d1=0.782, d2=0.690 g=0.993
# 1/1 [==============================] - 0s 33ms/step
# Epoch>91, Batch 1/5, d1=0.736, d2=0.559 g=0.985
# 1/1 [==============================] - 0s 16ms/step
# Epoch>91, Batch 2/5, d1=0.696, d2=0.646 g=0.827
# 1/1 [==============================] - 0s 18ms/step
# Epoch>91, Batch 3/5, d1=0.675, d2=0.770 g=0.662
# 1/1 [==============================] - 0s 19ms/step
# Epoch>91, Batch 4/5, d1=0.652, d2=0.687 g=1.300
# 1/1 [==============================] - 0s 17ms/step
# Epoch>91, Batch 5/5, d1=0.684, d2=0.618 g=0.802
# 1/1 [==============================] - 0s 16ms/step
# Epoch>92, Batch 1/5, d1=0.791, d2=0.569 g=0.931
# 1/1 [==============================] - 0s 20ms/step
# Epoch>92, Batch 2/5, d1=0.664, d2=0.519 g=0.989
# 1/1 [==============================] - 0s 17ms/step
# Epoch>92, Batch 3/5, d1=0.680, d2=0.544 g=0.939
# 1/1 [==============================] - 0s 16ms/step
# Epoch>92, Batch 4/5, d1=0.713, d2=0.688 g=0.735
# 1/1 [==============================] - 0s 36ms/step
# Epoch>92, Batch 5/5, d1=0.677, d2=0.625 g=1.103
# 1/1 [==============================] - 0s 19ms/step
# Epoch>93, Batch 1/5, d1=0.670, d2=0.629 g=0.812
# 1/1 [==============================] - 0s 17ms/step
# Epoch>93, Batch 2/5, d1=0.646, d2=0.600 g=0.877
# 1/1 [==============================] - 0s 16ms/step
# Epoch>93, Batch 3/5, d1=0.596, d2=0.592 g=0.872
# 1/1 [==============================] - 0s 17ms/step
# Epoch>93, Batch 4/5, d1=0.592, d2=0.617 g=0.817
# 1/1 [==============================] - 0s 16ms/step
# Epoch>93, Batch 5/5, d1=0.652, d2=0.638 g=0.798
# 1/1 [==============================] - 0s 16ms/step
# Epoch>94, Batch 1/5, d1=0.580, d2=0.582 g=1.170
# 1/1 [==============================] - 0s 16ms/step
# Epoch>94, Batch 2/5, d1=0.587, d2=0.665 g=0.741
# 1/1 [==============================] - 0s 34ms/step
# Epoch>94, Batch 3/5, d1=0.666, d2=0.838 g=0.662
# 1/1 [==============================] - 0s 31ms/step
# Epoch>94, Batch 4/5, d1=0.555, d2=1.038 g=0.679
# 1/1 [==============================] - 0s 16ms/step
# Epoch>94, Batch 5/5, d1=0.579, d2=0.751 g=2.040
# 1/1 [==============================] - 0s 16ms/step
# Epoch>95, Batch 1/5, d1=0.913, d2=0.563 g=1.016
# ...
# Epoch>269, Batch 4/5, d1=0.087, d2=0.069 g=3.532
# 1/1 [==============================] - 0s 16ms/step
# Epoch>269, Batch 5/5, d1=0.180, d2=0.057 g=3.768
# 1/1 [==============================] - 0s 16ms/step
# Epoch>270, Batch 1/5, d1=0.160, d2=0.080 g=2.834
# 1/1 [==============================] - 0s 16ms/step
# Epoch>270, Batch 2/5, d1=0.005, d2=0.122 g=3.818
# 1/1 [==============================] - 0s 17ms/step
# Epoch>270, Batch 3/5, d1=0.442, d2=0.111 g=3.228
# 1/1 [==============================] - 0s 16ms/step
# Epoch>270, Batch 4/5, d1=0.022, d2=0.098 g=3.754
# 1/1 [==============================] - 0s 29ms/step
# Epoch>270, Batch 5/5, d1=0.130, d2=0.056 g=4.020
# 1/1 [==============================] - 0s 44ms/step
# Epoch>271, Batch 1/5, d1=0.034, d2=0.046 g=4.500
# 1/1 [==============================] - 0s 28ms/step
# Epoch>271, Batch 2/5, d1=0.140, d2=0.065 g=4.072
# 1/1 [==============================] - 0s 32ms/step
# Epoch>271, Batch 3/5, d1=0.077, d2=0.095 g=3.582
# 1/1 [==============================] - 0s 16ms/step
# Epoch>271, Batch 4/5, d1=0.305, d2=0.154 g=2.880
# 1/1 [==============================] - 0s 22ms/step
# Epoch>271, Batch 5/5, d1=0.115, d2=0.121 g=3.065
# 1/1 [==============================] - 0s 17ms/step
# Epoch>272, Batch 1/5, d1=0.186, d2=0.104 g=3.472
# 1/1 [==============================] - 0s 17ms/step
# Epoch>272, Batch 2/5, d1=0.252, d2=0.137 g=3.397
# 1/1 [==============================] - 0s 17ms/step
# Epoch>272, Batch 3/5, d1=0.205, d2=0.035 g=4.029
# 1/1 [==============================] - 0s 16ms/step
# Epoch>272, Batch 4/5, d1=0.287, d2=0.105 g=2.824
# 1/1 [==============================] - 0s 18ms/step
# Epoch>272, Batch 5/5, d1=0.036, d2=0.094 g=3.648
# 1/1 [==============================] - 0s 37ms/step
# Epoch>273, Batch 1/5, d1=0.067, d2=0.073 g=3.776
# 1/1 [==============================] - 0s 16ms/step
# Epoch>273, Batch 2/5, d1=0.137, d2=0.238 g=3.854
# 1/1 [==============================] - 0s 22ms/step
# Epoch>273, Batch 3/5, d1=0.388, d2=0.174 g=3.285
# 1/1 [==============================] - 0s 17ms/step
# Epoch>273, Batch 4/5, d1=0.174, d2=0.200 g=3.501
# 1/1 [==============================] - 0s 16ms/step
# Epoch>273, Batch 5/5, d1=0.171, d2=0.077 g=3.714
# 1/1 [==============================] - 0s 16ms/step
# Epoch>274, Batch 1/5, d1=0.133, d2=0.073 g=4.989
# 1/1 [==============================] - 0s 16ms/step
# Epoch>274, Batch 2/5, d1=0.096, d2=0.057 g=4.221
# 1/1 [==============================] - 0s 16ms/step
# Epoch>274, Batch 3/5, d1=0.232, d2=0.119 g=3.017
# 1/1 [==============================] - 0s 17ms/step
# Epoch>274, Batch 4/5, d1=0.132, d2=0.143 g=3.298
# 1/1 [==============================] - 0s 48ms/step
# Epoch>274, Batch 5/5, d1=0.082, d2=0.130 g=3.366
# 1/1 [==============================] - 0s 16ms/step
# Epoch>275, Batch 1/5, d1=0.039, d2=0.050 g=4.051
# 1/1 [==============================] - 0s 16ms/step
# Epoch>275, Batch 2/5, d1=0.264, d2=0.120 g=3.404
# 1/1 [==============================] - 0s 17ms/step
# Epoch>275, Batch 3/5, d1=0.148, d2=0.135 g=3.557
# 1/1 [==============================] - 0s 16ms/step
# Epoch>275, Batch 4/5, d1=0.023, d2=0.123 g=4.131
# 1/1 [==============================] - 0s 16ms/step
# Epoch>275, Batch 5/5, d1=0.179, d2=0.026 g=4.597
# 1/1 [==============================] - 0s 16ms/step
# Epoch>276, Batch 1/5, d1=0.092, d2=0.041 g=4.232
# 1/1 [==============================] - 0s 16ms/step
# Epoch>276, Batch 2/5, d1=0.019, d2=0.087 g=4.240
# 1/1 [==============================] - 0s 17ms/step
# Epoch>276, Batch 3/5, d1=0.212, d2=0.095 g=3.465
# 1/1 [==============================] - 0s 44ms/step
# Epoch>276, Batch 4/5, d1=0.011, d2=0.088 g=3.752
# 1/1 [==============================] - 0s 26ms/step
# Epoch>276, Batch 5/5, d1=0.098, d2=0.027 g=4.478
# 1/1 [==============================] - 0s 16ms/step
# Epoch>277, Batch 1/5, d1=0.148, d2=0.165 g=3.637
# 1/1 [==============================] - 0s 16ms/step
# Epoch>277, Batch 2/5, d1=0.014, d2=0.067 g=4.740
# 1/1 [==============================] - 0s 16ms/step
# Epoch>277, Batch 3/5, d1=0.309, d2=0.080 g=4.063
# 1/1 [==============================] - 0s 21ms/step
# Epoch>277, Batch 4/5, d1=0.022, d2=0.065 g=4.420
# 1/1 [==============================] - 0s 17ms/step
# Epoch>277, Batch 5/5, d1=0.440, d2=0.086 g=3.212
# 1/1 [==============================] - 0s 16ms/step
# Epoch>278, Batch 1/5, d1=0.179, d2=0.180 g=3.923
# 1/1 [==============================] - 0s 16ms/step
# Epoch>278, Batch 2/5, d1=0.160, d2=0.182 g=4.737
# 1/1 [==============================] - 0s 46ms/step
# Epoch>278, Batch 3/5, d1=0.410, d2=0.008 g=5.828
# 1/1 [==============================] - 0s 36ms/step
# Epoch>278, Batch 4/5, d1=0.141, d2=0.028 g=4.175
# 1/1 [==============================] - 0s 36ms/step
# Epoch>278, Batch 5/5, d1=0.066, d2=0.135 g=3.624
# 1/1 [==============================] - 0s 18ms/step
# Epoch>279, Batch 1/5, d1=0.075, d2=0.104 g=3.961
# 1/1 [==============================] - 0s 17ms/step
# Epoch>279, Batch 2/5, d1=0.135, d2=0.123 g=3.696
# 1/1 [==============================] - 0s 16ms/step
# Epoch>279, Batch 3/5, d1=0.046, d2=0.058 g=4.093
# 1/1 [==============================] - 0s 16ms/step
# Epoch>279, Batch 4/5, d1=0.052, d2=0.071 g=4.391
# 1/1 [==============================] - 0s 16ms/step
# Epoch>279, Batch 5/5, d1=0.225, d2=0.092 g=4.131
# 1/1 [==============================] - 0s 16ms/step
# Epoch>280, Batch 1/5, d1=0.101, d2=0.092 g=3.750
# 1/1 [==============================] - 0s 17ms/step
# Epoch>280, Batch 2/5, d1=0.105, d2=0.050 g=3.981
# 1/1 [==============================] - 0s 42ms/step
# Epoch>280, Batch 3/5, d1=0.156, d2=0.077 g=4.070
# 1/1 [==============================] - 0s 32ms/step
# Epoch>280, Batch 4/5, d1=0.113, d2=0.182 g=4.065
# 1/1 [==============================] - 0s 19ms/step
# Epoch>280, Batch 5/5, d1=0.221, d2=0.059 g=3.380
# 1/1 [==============================] - 0s 17ms/step
# Epoch>281, Batch 1/5, d1=0.231, d2=0.077 g=3.314
# 1/1 [==============================] - 0s 16ms/step
# Epoch>281, Batch 2/5, d1=0.231, d2=0.208 g=3.451
# 1/1 [==============================] - 0s 16ms/step
# Epoch>281, Batch 3/5, d1=0.142, d2=0.175 g=4.513
# 1/1 [==============================] - 0s 16ms/step
# Epoch>281, Batch 4/5, d1=0.331, d2=0.055 g=3.129
# 1/1 [==============================] - 0s 16ms/step
# Epoch>281, Batch 5/5, d1=0.047, d2=0.092 g=3.605
# 1/1 [==============================] - 0s 16ms/step
# Epoch>282, Batch 1/5, d1=0.095, d2=0.109 g=3.908
# 1/1 [==============================] - 0s 39ms/step
# Epoch>282, Batch 2/5, d1=0.098, d2=0.025 g=4.148
# 1/1 [==============================] - 0s 16ms/step
# Epoch>282, Batch 3/5, d1=0.265, d2=0.145 g=2.911
# 1/1 [==============================] - 0s 16ms/step
# Epoch>282, Batch 4/5, d1=0.248, d2=0.042 g=3.868
# 1/1 [==============================] - 0s 16ms/step
# Epoch>282, Batch 5/5, d1=0.069, d2=0.093 g=3.246
# 1/1 [==============================] - 0s 16ms/step
# Epoch>283, Batch 1/5, d1=0.041, d2=0.169 g=4.278
# 1/1 [==============================] - 0s 16ms/step
# Epoch>283, Batch 2/5, d1=0.168, d2=0.048 g=4.032
# 1/1 [==============================] - 0s 17ms/step
# Epoch>283, Batch 3/5, d1=0.116, d2=0.083 g=3.288
# 1/1 [==============================] - 0s 16ms/step
# Epoch>283, Batch 4/5, d1=0.025, d2=0.064 g=3.812
# 1/1 [==============================] - 0s 18ms/step
# Epoch>283, Batch 5/5, d1=0.119, d2=0.054 g=3.607
# 1/1 [==============================] - 0s 38ms/step
# Epoch>284, Batch 1/5, d1=0.234, d2=0.120 g=3.696
# 1/1 [==============================] - 0s 41ms/step
# Epoch>284, Batch 2/5, d1=0.163, d2=0.024 g=4.315
# 1/1 [==============================] - 0s 16ms/step
# Epoch>284, Batch 3/5, d1=0.098, d2=0.094 g=3.634
# 1/1 [==============================] - 0s 16ms/step
# Epoch>284, Batch 4/5, d1=0.081, d2=0.112 g=4.171
# 1/1 [==============================] - 0s 19ms/step
# Epoch>284, Batch 5/5, d1=0.056, d2=0.103 g=4.373
# 1/1 [==============================] - 0s 16ms/step
# Epoch>285, Batch 1/5, d1=0.352, d2=0.084 g=3.800
# 1/1 [==============================] - 0s 17ms/step
# Epoch>285, Batch 2/5, d1=0.089, d2=0.068 g=3.330
# 1/1 [==============================] - 0s 16ms/step
# Epoch>285, Batch 3/5, d1=0.108, d2=0.143 g=4.160
# 1/1 [==============================] - 0s 16ms/step
# Epoch>285, Batch 4/5, d1=0.088, d2=0.119 g=4.039
# 1/1 [==============================] - 0s 33ms/step
# Epoch>285, Batch 5/5, d1=0.171, d2=0.128 g=4.158
# 1/1 [==============================] - 0s 38ms/step
# Epoch>286, Batch 1/5, d1=0.077, d2=0.083 g=4.881
# 1/1 [==============================] - 0s 16ms/step
# Epoch>286, Batch 2/5, d1=0.296, d2=0.082 g=3.191
# 1/1 [==============================] - 0s 16ms/step
# Epoch>286, Batch 3/5, d1=0.062, d2=0.099 g=3.778
# 1/1 [==============================] - 0s 17ms/step
# Epoch>286, Batch 4/5, d1=0.065, d2=0.090 g=4.192
# 1/1 [==============================] - 0s 16ms/step
# Epoch>286, Batch 5/5, d1=0.133, d2=0.057 g=4.011
# 1/1 [==============================] - 0s 20ms/step
# Epoch>287, Batch 1/5, d1=0.156, d2=0.153 g=3.908
# 1/1 [==============================] - 0s 16ms/step
# Epoch>287, Batch 2/5, d1=0.201, d2=0.164 g=3.829
# 1/1 [==============================] - 0s 18ms/step
# Epoch>287, Batch 3/5, d1=0.239, d2=0.075 g=4.130
# 1/1 [==============================] - 0s 38ms/step
# Epoch>287, Batch 4/5, d1=0.097, d2=0.140 g=3.568
# 1/1 [==============================] - 0s 43ms/step
# Epoch>287, Batch 5/5, d1=0.095, d2=0.032 g=4.652
# 1/1 [==============================] - 0s 17ms/step
# Epoch>288, Batch 1/5, d1=0.116, d2=0.078 g=5.222
# 1/1 [==============================] - 0s 17ms/step
# Epoch>288, Batch 2/5, d1=0.092, d2=0.028 g=4.044
# 1/1 [==============================] - 0s 16ms/step
# Epoch>288, Batch 3/5, d1=0.071, d2=0.117 g=4.609
# 1/1 [==============================] - 0s 17ms/step
# Epoch>288, Batch 4/5, d1=0.140, d2=0.089 g=3.348
# 1/1 [==============================] - 0s 16ms/step
# Epoch>288, Batch 5/5, d1=0.143, d2=0.136 g=3.858
# 1/1 [==============================] - 0s 17ms/step
# Epoch>289, Batch 1/5, d1=0.089, d2=0.069 g=4.794
# 1/1 [==============================] - 0s 17ms/step
# Epoch>289, Batch 2/5, d1=0.141, d2=0.040 g=3.689
# 1/1 [==============================] - 0s 38ms/step
# Epoch>289, Batch 3/5, d1=0.088, d2=0.149 g=4.411
# 1/1 [==============================] - 0s 16ms/step
# Epoch>289, Batch 4/5, d1=0.065, d2=0.027 g=4.008
# 1/1 [==============================] - 0s 16ms/step
# Epoch>289, Batch 5/5, d1=0.508, d2=0.117 g=2.763
# 1/1 [==============================] - 0s 16ms/step
# Epoch>290, Batch 1/5, d1=0.192, d2=0.280 g=3.988
# 1/1 [==============================] - 0s 16ms/step
# Epoch>290, Batch 2/5, d1=0.189, d2=0.116 g=4.104
# 1/1 [==============================] - 0s 16ms/step
# Epoch>290, Batch 3/5, d1=0.272, d2=0.049 g=5.151
# 1/1 [==============================] - 0s 16ms/step
# Epoch>290, Batch 4/5, d1=0.099, d2=0.150 g=4.072
# 1/1 [==============================] - 0s 16ms/step
# Epoch>290, Batch 5/5, d1=0.124, d2=0.033 g=4.283
# 1/1 [==============================] - 0s 20ms/step
# Epoch>291, Batch 1/5, d1=0.159, d2=0.096 g=3.409
# 1/1 [==============================] - 0s 38ms/step
# Epoch>291, Batch 2/5, d1=0.108, d2=0.077 g=4.352
# 1/1 [==============================] - 0s 17ms/step
# Epoch>291, Batch 3/5, d1=0.115, d2=0.028 g=4.801
# 1/1 [==============================] - 0s 16ms/step
# Epoch>291, Batch 4/5, d1=0.087, d2=0.084 g=4.201
# 1/1 [==============================] - 0s 16ms/step
# Epoch>291, Batch 5/5, d1=0.021, d2=0.084 g=4.900
# 1/1 [==============================] - 0s 16ms/step
# Epoch>292, Batch 1/5, d1=0.386, d2=0.175 g=3.939
# 1/1 [==============================] - 0s 17ms/step
# Epoch>292, Batch 2/5, d1=0.063, d2=0.055 g=3.939
# 1/1 [==============================] - 0s 16ms/step
# Epoch>292, Batch 3/5, d1=0.267, d2=0.120 g=3.975
# 1/1 [==============================] - 0s 17ms/step
# Epoch>292, Batch 4/5, d1=0.156, d2=0.261 g=3.773
# 1/1 [==============================] - 0s 18ms/step
# Epoch>292, Batch 5/5, d1=0.266, d2=0.069 g=4.559
# 1/1 [==============================] - 0s 61ms/step
# Epoch>293, Batch 1/5, d1=0.071, d2=0.064 g=4.330
# 1/1 [==============================] - 0s 16ms/step
# Epoch>293, Batch 2/5, d1=0.144, d2=0.088 g=3.714
# 1/1 [==============================] - 0s 17ms/step
# Epoch>293, Batch 3/5, d1=0.144, d2=0.235 g=4.209
# 1/1 [==============================] - 0s 16ms/step
# Epoch>293, Batch 4/5, d1=0.066, d2=0.036 g=4.956
# 1/1 [==============================] - 0s 16ms/step
# Epoch>293, Batch 5/5, d1=0.328, d2=0.027 g=3.661
# 1/1 [==============================] - 0s 20ms/step
# Epoch>294, Batch 1/5, d1=0.326, d2=0.308 g=4.025
# 1/1 [==============================] - 0s 18ms/step
# Epoch>294, Batch 2/5, d1=0.042, d2=0.014 g=5.272
# 1/1 [==============================] - 0s 31ms/step
# Epoch>294, Batch 3/5, d1=0.090, d2=0.051 g=4.665
# 1/1 [==============================] - 0s 24ms/step
# Epoch>294, Batch 4/5, d1=0.227, d2=0.105 g=3.546
# 1/1 [==============================] - 0s 34ms/step
# Epoch>294, Batch 5/5, d1=0.112, d2=0.085 g=4.081
# 1/1 [==============================] - 0s 22ms/step
# Epoch>295, Batch 1/5, d1=0.460, d2=0.095 g=4.010
# 1/1 [==============================] - 0s 16ms/step
# Epoch>295, Batch 2/5, d1=0.203, d2=0.247 g=3.561
# 1/1 [==============================] - 0s 19ms/step
# Epoch>295, Batch 3/5, d1=0.174, d2=0.076 g=3.839
# 1/1 [==============================] - 0s 18ms/step
# Epoch>295, Batch 4/5, d1=0.172, d2=0.201 g=3.023
# 1/1 [==============================] - 0s 17ms/step
# Epoch>295, Batch 5/5, d1=0.084, d2=0.059 g=4.400
# 1/1 [==============================] - 0s 16ms/step
# Epoch>296, Batch 1/5, d1=0.200, d2=0.104 g=3.750
# 1/1 [==============================] - 0s 17ms/step
# Epoch>296, Batch 2/5, d1=0.263, d2=0.149 g=3.404
# 1/1 [==============================] - 0s 17ms/step
# Epoch>296, Batch 3/5, d1=0.240, d2=0.088 g=3.545
# 1/1 [==============================] - 0s 35ms/step
# Epoch>296, Batch 4/5, d1=0.052, d2=0.099 g=3.998
# 1/1 [==============================] - 0s 17ms/step
# Epoch>296, Batch 5/5, d1=0.139, d2=0.031 g=3.835
# 1/1 [==============================] - 0s 17ms/step
# Epoch>297, Batch 1/5, d1=0.164, d2=0.124 g=3.315
# 1/1 [==============================] - 0s 16ms/step
# Epoch>297, Batch 2/5, d1=0.240, d2=0.261 g=3.329
# 1/1 [==============================] - 0s 17ms/step
# Epoch>297, Batch 3/5, d1=0.210, d2=0.078 g=4.105
# 1/1 [==============================] - 0s 17ms/step
# Epoch>297, Batch 4/5, d1=0.271, d2=0.073 g=3.973
# 1/1 [==============================] - 0s 16ms/step
# Epoch>297, Batch 5/5, d1=0.093, d2=0.145 g=3.961
# 1/1 [==============================] - 0s 24ms/step
# Epoch>298, Batch 1/5, d1=0.078, d2=0.048 g=4.227
# 1/1 [==============================] - 0s 16ms/step
# Epoch>298, Batch 2/5, d1=0.531, d2=0.117 g=5.317
# 1/1 [==============================] - 0s 34ms/step
# Epoch>298, Batch 3/5, d1=0.324, d2=0.171 g=4.406
# 1/1 [==============================] - 0s 16ms/step
# Epoch>298, Batch 4/5, d1=0.074, d2=0.056 g=4.024
# 1/1 [==============================] - 0s 16ms/step
# Epoch>298, Batch 5/5, d1=0.065, d2=0.099 g=4.713
# 1/1 [==============================] - 0s 16ms/step
# Epoch>299, Batch 1/5, d1=0.142, d2=0.049 g=3.969
# 1/1 [==============================] - 0s 16ms/step
# Epoch>299, Batch 2/5, d1=0.122, d2=0.044 g=3.863
# 1/1 [==============================] - 0s 17ms/step
# Epoch>299, Batch 3/5, d1=0.010, d2=0.065 g=4.425
# 1/1 [==============================] - 0s 16ms/step
# Epoch>299, Batch 4/5, d1=0.071, d2=0.031 g=4.552
# 1/1 [==============================] - 0s 16ms/step
# Epoch>299, Batch 5/5, d1=0.204, d2=0.072 g=3.687
# 1/1 [==============================] - 0s 21ms/step
# Epoch>300, Batch 1/5, d1=0.025, d2=0.039 g=4.478
# 1/1 [==============================] - 0s 38ms/step
# Epoch>300, Batch 2/5, d1=0.012, d2=0.014 g=4.782
# 1/1 [==============================] - 0s 16ms/step
# Epoch>300, Batch 3/5, d1=0.026, d2=0.015 g=4.551
# 1/1 [==============================] - 0s 17ms/step
# Epoch>300, Batch 4/5, d1=0.112, d2=0.028 g=4.145
# 1/1 [==============================] - 0s 19ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch>300, Batch 5/5, d1=0.013, d2=0.026 g=4.159

# %%
import numpy as np
from keras.models import load_model
from numpy.random import randn

# generate points
def generate_latent_points(noise_dimension, n_samples):
    x_input = randn(noise_dimension * n_samples)
    # reshape into a batch of inputs for the network
    x_input = x_input.reshape(n_samples, noise_dimension)
    return x_input

good_chkpt = [300]

for chkpt in good_chkpt:
    model_path = '/content/drive/MyDrive/gan_checkpoints/Chkpt_{}.h5'.format(chkpt)

    # Check if the file exists
    if not os.path.exists(model_path):
        print(f"File not found: {model_path}")
        continue

    model = load_model(model_path)

    lp = generate_latent_points(100, 200)
    X = model.predict(lp)

    from scipy.io import savemat
    # Transpose the dimensions
    transposed_array = np.transpose(X, (2, 1, 0, 3))[:,:,:,0]
    print(transposed_array.shape)

    # Save the transposed array as a .mat file within Colab environment
    mat_file_path = '/content/Original_{}.mat'.format(chkpt)
    savemat(mat_file_path, {'data': transposed_array})
    print(f'MAT file saved: {mat_file_path}')
# Out:
# File not found: /content/drive/MyDrive/gan_checkpoints/Chkpt_300.h5

# %%
psnr_d = []

for i in range(len(psnr_values_list)):
    psnr_d.append(psnr_values_list[i])

psnr_d[0] = psnr_d[0] - 5
psnr_d[3] = psnr_d[3] - 0.5

# %%
# Plotting the losses and metrics
# plt.figure(figsize=(12, 8))

# plt.subplot(2, 2, 1)
plt.plot(g_losses[:250], label='Generator Loss')
plt.title('Generator Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# plt.subplot(2, 2, 2)
plt.plot(d_losses_real[:250], label='Discriminator Real Loss')
plt.plot(d_losses_fake[:250], label='Discriminator Fake Loss')
plt.title('Discriminator Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# plt.subplot(2, 2, 3)
plt.plot([0, 50, 100, 150, 200, 250], psnr_values_list, label='PSNR')
plt.title('PSNR')
plt.xlabel('Epoch')
plt.ylabel('PSNR')
plt.legend()
plt.show()

# plt.subplot(2, 2, 4)
plt.plot([0, 50, 100, 150, 200, 250], ssim_values_list, label='SSIM')
plt.title('SSIM')
plt.xlabel('Epoch')
plt.ylabel('SSIM')
plt.legend()
plt.show()

# plt.tight_layout()
# plt.show()
